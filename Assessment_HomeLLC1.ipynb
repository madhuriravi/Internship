# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
#key factor unemployment rate that influence house price from fred
un_emp_rate=pd.read_csv("C:\\Users\\Ravi\\Downloads\\UNRATE.csv")
un_emp_rate
# Out:
#            DATE  UNRATE
# 0    1948-01-01     3.4
# 1    1948-02-01     3.8
# 2    1948-03-01     4.0
# 3    1948-04-01     3.9
# 4    1948-05-01     3.5
# ..          ...     ...
# 906  2023-07-01     3.5
# 907  2023-08-01     3.8
# 908  2023-09-01     3.8
# 909  2023-10-01     3.9
# 910  2023-11-01     3.7
#
# [911 rows x 2 columns]

# %%
#consumer price index for all urban consumers
con_pr=pd.read_csv("C:\\Users\\Ravi\\Downloads\\CPIAUCSL.csv")
con_pr
# Out:
#            DATE  CPIAUCSL
# 0    1947-01-01    21.480
# 1    1947-02-01    21.620
# 2    1947-03-01    22.000
# 3    1947-04-01    22.000
# 4    1947-05-01    21.950
# ..          ...       ...
# 917  2023-06-01   303.841
# 918  2023-07-01   304.348
# 919  2023-08-01   306.269
# 920  2023-09-01   307.481
# 921  2023-10-01   307.619
#
# [922 rows x 2 columns]

# %%
#real gross domestic product
rgdp=pd.read_csv("C:\\Users\\Ravi\\Downloads\\GDPC1.csv")
rgdp
# Out:
#            DATE  GDPC1_CCH
# 0    1947-04-01   -0.26558
# 1    1947-07-01   -0.20509
# 2    1947-10-01    1.55385
# 3    1948-01-01    1.49481
# 4    1948-04-01    1.63887
# ..          ...        ...
# 301  2022-07-01    0.65646
# 302  2022-10-01    0.63341
# 303  2023-01-01    0.55484
# 304  2023-04-01    0.50982
# 305  2023-07-01    1.25646
#
# [306 rows x 2 columns]

# %%
#Industrial production
ind_pro=pd.read_csv("C:\\Users\\Ravi\\Downloads\\INDPRO.csv")
ind_pro
# Out:
#             DATE    INDPRO
# 0     1919-01-01    4.8665
# 1     1919-02-01    4.6514
# 2     1919-03-01    4.5170
# 3     1919-04-01    4.5976
# 4     1919-05-01    4.6245
# ...          ...       ...
# 1253  2023-06-01  102.3030
# 1254  2023-07-01  103.2670
# 1255  2023-08-01  103.2927
# 1256  2023-09-01  103.3643
# 1257  2023-10-01  102.7081
#
# [1258 rows x 2 columns]

# %%
#All employees,Total nonfarm
pay_roll=pd.read_csv("C:\\Users\\Ravi\\Downloads\\PAYEMS.csv")
pay_roll
# Out:
#             DATE  PAYEMS
# 0     1939-01-01   29923
# 1     1939-02-01   30100
# 2     1939-03-01   30280
# 3     1939-04-01   30094
# 4     1939-05-01   30299
# ...          ...     ...
# 1014  2023-07-01  156311
# 1015  2023-08-01  156476
# 1016  2023-09-01  156738
# 1017  2023-10-01  156888
# 1018  2023-11-01  157087
#
# [1019 rows x 2 columns]

# %%
#National home price index
n_h_p=pd.read_csv("C:\\Users\\Ravi\\Downloads\\CSUSHPISA.csv")
n_h_p
# Out:
#            DATE  CSUSHPISA
# 0    1987-01-01     63.965
# 1    1987-02-01     64.424
# 2    1987-03-01     64.736
# 3    1987-04-01     65.132
# 4    1987-05-01     65.563
# ..          ...        ...
# 436  2023-05-01    302.566
# 437  2023-06-01    304.593
# 438  2023-07-01    306.767
# 439  2023-08-01    309.155
# 440  2023-09-01    311.175
#
# [441 rows x 2 columns]

# %%
#home price index of all states
h_p_s=pd.read_csv("C:\\Users\\Ravi\\Downloads\\fredgraph.csv")
h_p_s
# Out:
#            DATE  CSUSHPISA   SPCS10RSA              DEXRSA      LVXRSA  \
# 0    1987-01-01     63.965   63.103814                   .   66.418966
# 1    1987-02-01     64.424   63.804972                   .   67.574198
# 2    1987-03-01     64.736   64.425674                   .   67.850132
# 3    1987-04-01     65.132   65.063393                   .   68.186064
# 4    1987-05-01     65.563   65.815103                   .   67.927091
# ..          ...        ...         ...                 ...         ...
# 436  2023-05-01    302.566  321.821685    174.601370604909  270.529911
# 437  2023-06-01    304.593  324.819718    175.130261785276  271.884431
# 438  2023-07-01    306.767  327.816609  176.34682368590902  274.394586
# 439  2023-08-01    309.155  330.747478  178.17720761544498  277.326438
# 440  2023-09-01    311.175  333.074427    180.535270393171  281.363656
#
#          LXXRSA      MIXRSA              MNXRSA      NYXRSA  \
# ...

# %%
#u.s.national home price index
u_s_h=pd.read_csv("C:\\Users\\Ravi\\Downloads\\alfredgraph.csv")
u_s_h
# Out:
#            DATE  CSUSHPISA_20231031  CSUSHPISA_20231128
# 0    1989-04-01              75.086              75.086
# 1    1989-05-01              75.306              75.306
# 2    1989-06-01              75.479              75.479
# 3    1989-07-01              75.657              75.657
# 4    1989-08-01              75.835              75.835
# ..          ...                 ...                 ...
# 404  2022-12-01             297.471             297.413
# 405  2023-01-01             297.025             297.030
# 406  2023-02-01             297.464             297.537
# 407  2023-03-01             298.539             298.637
# 408  2023-04-01             300.198             300.213
#
# [409 rows x 3 columns]

# %%
un_emp_rate.DATE=pd.to_datetime(un_emp_rate.DATE)
con_pr.DATE=pd.to_datetime(con_pr.DATE)
ind_pro.DATE=pd.to_datetime(ind_pro.DATE)
pay_roll.DATE=pd.to_datetime(pay_roll.DATE)
n_h_p.DATE=pd.to_datetime(h_p_s.DATE)
h_p_s.DATE=pd.to_datetime(h_p_s.DATE)
u_s_h.DATE = pd.to_datetime(u_s_h.DATE)

# %%
## creating the function to convert the date time format of all the parameters to YYYY-MM-DD

def date_col(arr):
    arr = arr.str.replace(" ","-")
    for i in range(len(arr)):
        arr[i]=dt.datetime.strptime(arr[i], '%d-%m-%y').strftime('%Y-%m-%d')
    return arr

# %%
files=["UNRATE","CPIAUCSL","INDPRO","PAYEMS","CSUSHPISA","fredgraph","alfredgraph"]
for i in range(len(files)-1):
    temp=pd.read_csv(files[i]+'.csv')
    if len(temp.iloc[0,0])==8:
        temp.iloc[:,0] = date_col(temp.iloc[:,0])
    temp.DATE=pd.to_datetime(temp.DATE)
    df=pd.merge(left=un_emp_rate,right=temp, left_on='DATE', right_on='DATE',how='left')

# %%
df
# Out:
#           DATE  UNRATE  CSUSHPISA   SPCS10RSA              DEXRSA      LVXRSA  \
# 0   1948-01-01     3.4        NaN         NaN                 NaN         NaN
# 1   1948-02-01     3.8        NaN         NaN                 NaN         NaN
# 2   1948-03-01     4.0        NaN         NaN                 NaN         NaN
# 3   1948-04-01     3.9        NaN         NaN                 NaN         NaN
# 4   1948-05-01     3.5        NaN         NaN                 NaN         NaN
# ..         ...     ...        ...         ...                 ...         ...
# 906 2023-07-01     3.5    306.767  327.816609  176.34682368590902  274.394586
# 907 2023-08-01     3.8    309.155  330.747478  178.17720761544498  277.326438
# 908 2023-09-01     3.8    311.175  333.074427    180.535270393171  281.363656
# 909 2023-10-01     3.9        NaN         NaN                 NaN         NaN
# 910 2023-11-01     3.7        NaN         NaN                 NaN         NaN
#
# ...

# %%
df.shape
# Out:
# (911, 14)

# %%
df.columns
# Out:
# Index(['DATE', 'UNRATE', 'CSUSHPISA', 'SPCS10RSA', 'DEXRSA', 'LVXRSA',
#        'LXXRSA', 'MIXRSA', 'MNXRSA', 'NYXRSA', 'PHXRSA', 'POXRSA', 'SDXRSA',
#        'SFXRSA'],
#       dtype='object')

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 906    False
# 907    False
# 908    False
# 909    False
# 910    False
# Length: 911, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum().sum()
# Out:
# 5640

# %%
df.isnull().sum()
# Out:
# DATE           0
# UNRATE         0
# CSUSHPISA    470
# SPCS10RSA    470
# DEXRSA       470
# LVXRSA       470
# LXXRSA       470
# MIXRSA       470
# MNXRSA       470
# NYXRSA       470
# PHXRSA       470
# POXRSA       470
# SDXRSA       470
# SFXRSA       470
# dtype: int64

# %%
df.bfill(axis=None, inplace=True, limit=None, downcast=None)

# %%
df.isnull().sum()
# Out:
# DATE         0
# UNRATE       0
# CSUSHPISA    2
# SPCS10RSA    2
# DEXRSA       2
# LVXRSA       2
# LXXRSA       2
# MIXRSA       2
# MNXRSA       2
# NYXRSA       2
# PHXRSA       2
# POXRSA       2
# SDXRSA       2
# SFXRSA       2
# dtype: int64

# %%
df
# Out:
#           DATE  UNRATE  CSUSHPISA   SPCS10RSA              DEXRSA      LVXRSA  \
# 0   1948-01-01     3.4     63.965   63.103814                   .   66.418966
# 1   1948-02-01     3.8     63.965   63.103814                   .   66.418966
# 2   1948-03-01     4.0     63.965   63.103814                   .   66.418966
# 3   1948-04-01     3.9     63.965   63.103814                   .   66.418966
# 4   1948-05-01     3.5     63.965   63.103814                   .   66.418966
# ..         ...     ...        ...         ...                 ...         ...
# 906 2023-07-01     3.5    306.767  327.816609  176.34682368590902  274.394586
# 907 2023-08-01     3.8    309.155  330.747478  178.17720761544498  277.326438
# 908 2023-09-01     3.8    311.175  333.074427    180.535270393171  281.363656
# 909 2023-10-01     3.9        NaN         NaN                 NaN         NaN
# 910 2023-11-01     3.7        NaN         NaN                 NaN         NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 911 entries, 0 to 910
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   DATE       911 non-null    datetime64[ns]
#  1   UNRATE     911 non-null    float64
#  2   CSUSHPISA  909 non-null    float64
#  3   SPCS10RSA  909 non-null    float64
#  4   DEXRSA     909 non-null    object
#  5   LVXRSA     909 non-null    float64
#  6   LXXRSA     909 non-null    float64
#  7   MIXRSA     909 non-null    float64
#  8   MNXRSA     909 non-null    object
#  9   NYXRSA     909 non-null    float64
#  10  PHXRSA     909 non-null    object
#  11  POXRSA     909 non-null    float64
#  12  SDXRSA     909 non-null    float64
#  13  SFXRSA     909 non-null    float64
# dtypes: datetime64[ns](1), float64(10), object(3)
# memory usage: 106.8+ KB

# %%
for i in df.columns:
    print(df[i].value_counts())
# Out:
# 1948-01-01    1
# 2000-03-01    1
# 1998-01-01    1
# 1998-02-01    1
# 1998-03-01    1
#              ..
# 1973-08-01    1
# 1973-09-01    1
# 1973-10-01    1
# 1973-11-01    1
# 2023-11-01    1
# Name: DATE, Length: 911, dtype: int64
# 5.4     34
# 5.7     33
# 5.6     32
# 3.8     30
# 5.9     29
#         ..
# 9.2      1
# 2.8      1
# 10.3     1
# 8.9      1
# 11.0     1
# Name: UNRATE, Length: 83, dtype: int64
# 63.965     469
# 76.056       2
# 140.010      1
# 136.533      1
# 136.607      1
#           ...
# 93.672       1
# 93.208       1
# 92.712       1
# 92.199       1
# 311.175      1
# Name: CSUSHPISA, Length: 440, dtype: int64
# 63.103814     469
# 154.025704      1
# 149.644566      1
# 149.985472      1
# 150.377271      1
#              ...
# 90.710068       1
# 90.137675       1
# 89.731975       1
# 89.345365       1
# 333.074427      1
# Name: SPCS10RSA, Length: 441, dtype: int64
# .                     516
# 87.780933026772         1
# ...

# %%
df.replace('.','nan')
# Out:
#           DATE  UNRATE  CSUSHPISA   SPCS10RSA              DEXRSA      LVXRSA  \
# 0   1948-01-01     3.4     63.965   63.103814                 nan   66.418966
# 1   1948-02-01     3.8     63.965   63.103814                 nan   66.418966
# 2   1948-03-01     4.0     63.965   63.103814                 nan   66.418966
# 3   1948-04-01     3.9     63.965   63.103814                 nan   66.418966
# 4   1948-05-01     3.5     63.965   63.103814                 nan   66.418966
# ..         ...     ...        ...         ...                 ...         ...
# 906 2023-07-01     3.5    306.767  327.816609  176.34682368590902  274.394586
# 907 2023-08-01     3.8    309.155  330.747478  178.17720761544498  277.326438
# 908 2023-09-01     3.8    311.175  333.074427    180.535270393171  281.363656
# 909 2023-10-01     3.9        NaN         NaN                 NaN         NaN
# 910 2023-11-01     3.7        NaN         NaN                 NaN         NaN
#
# ...

# %%
df.bfill(axis=None, inplace=True, limit=None, downcast=None)

# %%
df.isnull().sum()
# Out:
# DATE         0
# UNRATE       0
# CSUSHPISA    2
# SPCS10RSA    2
# DEXRSA       2
# LVXRSA       2
# LXXRSA       2
# MIXRSA       2
# MNXRSA       2
# NYXRSA       2
# PHXRSA       2
# POXRSA       2
# SDXRSA       2
# SFXRSA       2
# dtype: int64

# %%
df.ffill(axis=None, inplace=True, limit=None, downcast=None)

# %%
df.isnull().sum()
# Out:
# DATE         0
# UNRATE       0
# CSUSHPISA    0
# SPCS10RSA    0
# DEXRSA       0
# LVXRSA       0
# LXXRSA       0
# MIXRSA       0
# MNXRSA       0
# NYXRSA       0
# PHXRSA       0
# POXRSA       0
# SDXRSA       0
# SFXRSA       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 911 entries, 0 to 910
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   DATE       911 non-null    datetime64[ns]
#  1   UNRATE     911 non-null    float64
#  2   CSUSHPISA  911 non-null    float64
#  3   SPCS10RSA  911 non-null    float64
#  4   DEXRSA     911 non-null    object
#  5   LVXRSA     911 non-null    float64
#  6   LXXRSA     911 non-null    float64
#  7   MIXRSA     911 non-null    float64
#  8   MNXRSA     911 non-null    object
#  9   NYXRSA     911 non-null    float64
#  10  PHXRSA     911 non-null    object
#  11  POXRSA     911 non-null    float64
#  12  SDXRSA     911 non-null    float64
#  13  SFXRSA     911 non-null    float64
# dtypes: datetime64[ns](1), float64(10), object(3)
# memory usage: 106.8+ KB

# %%
df1=pd.merge(pay_roll,ind_pro)

# %%
df1
# Out:
#            DATE  PAYEMS    INDPRO
# 0    1939-01-01   29923    7.0443
# 1    1939-02-01   30100    7.0981
# 2    1939-03-01   30280    7.1250
# 3    1939-04-01   30094    7.0981
# 4    1939-05-01   30299    7.0712
# ...         ...     ...       ...
# 1013 2023-06-01  156075  102.3030
# 1014 2023-07-01  156311  103.2670
# 1015 2023-08-01  156476  103.2927
# 1016 2023-09-01  156738  103.3643
# 1017 2023-10-01  156888  102.7081
#
# [1018 rows x 3 columns]

# %%
df
# Out:
#           DATE  UNRATE  CSUSHPISA   SPCS10RSA              DEXRSA      LVXRSA  \
# 0   1948-01-01     3.4     63.965   63.103814                   .   66.418966
# 1   1948-02-01     3.8     63.965   63.103814                   .   66.418966
# 2   1948-03-01     4.0     63.965   63.103814                   .   66.418966
# 3   1948-04-01     3.9     63.965   63.103814                   .   66.418966
# 4   1948-05-01     3.5     63.965   63.103814                   .   66.418966
# ..         ...     ...        ...         ...                 ...         ...
# 906 2023-07-01     3.5    306.767  327.816609  176.34682368590902  274.394586
# 907 2023-08-01     3.8    309.155  330.747478  178.17720761544498  277.326438
# 908 2023-09-01     3.8    311.175  333.074427    180.535270393171  281.363656
# 909 2023-10-01     3.9    311.175  333.074427    180.535270393171  281.363656
# 910 2023-11-01     3.7    311.175  333.074427    180.535270393171  281.363656
#
# ...

# %%
df2=pd.merge(df,df1)
df2
# Out:
#           DATE  UNRATE  CSUSHPISA   SPCS10RSA              DEXRSA      LVXRSA  \
# 0   1948-01-01     3.4     63.965   63.103814                   .   66.418966
# 1   1948-02-01     3.8     63.965   63.103814                   .   66.418966
# 2   1948-03-01     4.0     63.965   63.103814                   .   66.418966
# 3   1948-04-01     3.9     63.965   63.103814                   .   66.418966
# 4   1948-05-01     3.5     63.965   63.103814                   .   66.418966
# ..         ...     ...        ...         ...                 ...         ...
# 905 2023-06-01     3.6    304.593  324.819718    175.130261785276  271.884431
# 906 2023-07-01     3.5    306.767  327.816609  176.34682368590902  274.394586
# 907 2023-08-01     3.8    309.155  330.747478  178.17720761544498  277.326438
# 908 2023-09-01     3.8    311.175  333.074427    180.535270393171  281.363656
# 909 2023-10-01     3.9    311.175  333.074427    180.535270393171  281.363656
#
# ...

# %%
df3=pd.merge(u_s_h,con_pr)
df3
# Out:
#           DATE  CSUSHPISA_20231031  CSUSHPISA_20231128  CPIAUCSL
# 0   1989-04-01              75.086              75.086   123.100
# 1   1989-05-01              75.306              75.306   123.700
# 2   1989-06-01              75.479              75.479   124.100
# 3   1989-07-01              75.657              75.657   124.500
# 4   1989-08-01              75.835              75.835   124.500
# ..         ...                 ...                 ...       ...
# 404 2022-12-01             297.471             297.413   298.990
# 405 2023-01-01             297.025             297.030   300.536
# 406 2023-02-01             297.464             297.537   301.648
# 407 2023-03-01             298.539             298.637   301.808
# 408 2023-04-01             300.198             300.213   302.918
#
# [409 rows x 4 columns]

# %%
df4=pd.merge(df2,df3)
df4
# Out:
#           DATE  UNRATE  CSUSHPISA   SPCS10RSA              DEXRSA      LVXRSA  \
# 0   1989-04-01     5.2     75.086   80.441948                   .   69.997252
# 1   1989-05-01     5.2     75.306   80.831878                   .   69.788148
# 2   1989-06-01     5.3     75.479   81.073507                   .   71.554147
# 3   1989-07-01     5.2     75.657   81.139316                   .   71.771789
# 4   1989-08-01     5.2     75.835   81.403008                   .   72.390032
# ..         ...     ...        ...         ...                 ...         ...
# 404 2022-12-01     3.5    297.413  314.634797  168.70302008352698  276.602762
# 405 2023-01-01     3.4    297.030  314.093523    168.612725299158  273.921557
# 406 2023-02-01     3.6    297.537  314.426445    168.162693483706  271.856550
# 407 2023-03-01     3.5    298.637  315.906003    170.463589594908  270.568432
# 408 2023-04-01     3.4    300.213  318.533061    172.099689790881  270.271411
#
# ...

# %%
df4.replace('.','nan')
# Out:
#           DATE  UNRATE  CSUSHPISA   SPCS10RSA              DEXRSA      LVXRSA  \
# 0   1989-04-01     5.2     75.086   80.441948                 nan   69.997252
# 1   1989-05-01     5.2     75.306   80.831878                 nan   69.788148
# 2   1989-06-01     5.3     75.479   81.073507                 nan   71.554147
# 3   1989-07-01     5.2     75.657   81.139316                 nan   71.771789
# 4   1989-08-01     5.2     75.835   81.403008                 nan   72.390032
# ..         ...     ...        ...         ...                 ...         ...
# 404 2022-12-01     3.5    297.413  314.634797  168.70302008352698  276.602762
# 405 2023-01-01     3.4    297.030  314.093523    168.612725299158  273.921557
# 406 2023-02-01     3.6    297.537  314.426445    168.162693483706  271.856550
# 407 2023-03-01     3.5    298.637  315.906003    170.463589594908  270.568432
# 408 2023-04-01     3.4    300.213  318.533061    172.099689790881  270.271411
#
# ...

# %%
df4.bfill(axis=None, inplace=True, limit=None, downcast=None)
df4
# Out:
#           DATE  UNRATE  CSUSHPISA   SPCS10RSA              DEXRSA      LVXRSA  \
# 0   1989-04-01     5.2     75.086   80.441948                   .   69.997252
# 1   1989-05-01     5.2     75.306   80.831878                   .   69.788148
# 2   1989-06-01     5.3     75.479   81.073507                   .   71.554147
# 3   1989-07-01     5.2     75.657   81.139316                   .   71.771789
# 4   1989-08-01     5.2     75.835   81.403008                   .   72.390032
# ..         ...     ...        ...         ...                 ...         ...
# 404 2022-12-01     3.5    297.413  314.634797  168.70302008352698  276.602762
# 405 2023-01-01     3.4    297.030  314.093523    168.612725299158  273.921557
# 406 2023-02-01     3.6    297.537  314.426445    168.162693483706  271.856550
# 407 2023-03-01     3.5    298.637  315.906003    170.463589594908  270.568432
# 408 2023-04-01     3.4    300.213  318.533061    172.099689790881  270.271411
#
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 409 entries, 0 to 408
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   DATE                409 non-null    datetime64[ns]
#  1   UNRATE              409 non-null    float64
#  2   CSUSHPISA           409 non-null    float64
#  3   SPCS10RSA           409 non-null    float64
#  4   DEXRSA              409 non-null    object
#  5   LVXRSA              409 non-null    float64
#  6   LXXRSA              409 non-null    float64
#  7   MIXRSA              409 non-null    float64
#  8   MNXRSA              409 non-null    object
#  9   NYXRSA              409 non-null    float64
#  10  PHXRSA              409 non-null    object
#  11  POXRSA              409 non-null    float64
#  12  SDXRSA              409 non-null    float64
#  13  SFXRSA              409 non-null    float64
#  14  PAYEMS              409 non-null    int64
# ...

# %%
for i in df4.columns:
    print(df4[i].value_counts())
# Out:
# 1989-04-01    1
# 2011-09-01    1
# 2012-07-01    1
# 2012-06-01    1
# 2012-05-01    1
#              ..
# 2000-06-01    1
# 2000-05-01    1
# 2000-04-01    1
# 2000-03-01    1
# 2023-04-01    1
# Name: DATE, Length: 409, dtype: int64
# 5.4    18
# 5.6    17
# 5.0    15
# 4.7    15
# 5.2    14
#        ..
# 8.1     1
# 8.5     1
# 8.6     1
# 8.8     1
# 8.7     1
# Name: UNRATE, Length: 68, dtype: int64
# 76.056     2
# 75.086     1
# 137.952    1
# 142.279    1
# 141.669    1
#           ..
# 105.054    1
# 104.424    1
# 103.678    1
# 102.922    1
# 300.213    1
# Name: CSUSHPISA, Length: 408, dtype: int64
# 80.441948     1
# 152.833801    1
# 154.503094    1
# 153.578835    1
# 152.043904    1
#              ..
# 107.335543    1
# 106.011979    1
# 104.530843    1
# 103.154350    1
# 318.533061    1
# Name: SPCS10RSA, Length: 409, dtype: int64
# .                     21
# 66.867495727982        1
# 82.45419792057601      1
# 82.237265947706        1
# 81.32629105730099      1
# ...

# %%
df4
# Out:
#           DATE  UNRATE  CSUSHPISA   SPCS10RSA              DEXRSA      LVXRSA  \
# 0   1989-04-01     5.2     75.086   80.441948                   .   69.997252
# 1   1989-05-01     5.2     75.306   80.831878                   .   69.788148
# 2   1989-06-01     5.3     75.479   81.073507                   .   71.554147
# 3   1989-07-01     5.2     75.657   81.139316                   .   71.771789
# 4   1989-08-01     5.2     75.835   81.403008                   .   72.390032
# ..         ...     ...        ...         ...                 ...         ...
# 404 2022-12-01     3.5    297.413  314.634797  168.70302008352698  276.602762
# 405 2023-01-01     3.4    297.030  314.093523    168.612725299158  273.921557
# 406 2023-02-01     3.6    297.537  314.426445    168.162693483706  271.856550
# 407 2023-03-01     3.5    298.637  315.906003    170.463589594908  270.568432
# 408 2023-04-01     3.4    300.213  318.533061    172.099689790881  270.271411
#
# ...

# %%
df4["DEXRSA"].replace(".","nan",inplace=True)

# %%
df4
# Out:
#           DATE  UNRATE  CSUSHPISA   SPCS10RSA              DEXRSA      LVXRSA  \
# 0   1989-04-01     5.2     75.086   80.441948                 nan   69.997252
# 1   1989-05-01     5.2     75.306   80.831878                 nan   69.788148
# 2   1989-06-01     5.3     75.479   81.073507                 nan   71.554147
# 3   1989-07-01     5.2     75.657   81.139316                 nan   71.771789
# 4   1989-08-01     5.2     75.835   81.403008                 nan   72.390032
# ..         ...     ...        ...         ...                 ...         ...
# 404 2022-12-01     3.5    297.413  314.634797  168.70302008352698  276.602762
# 405 2023-01-01     3.4    297.030  314.093523    168.612725299158  273.921557
# 406 2023-02-01     3.6    297.537  314.426445    168.162693483706  271.856550
# 407 2023-03-01     3.5    298.637  315.906003    170.463589594908  270.568432
# 408 2023-04-01     3.4    300.213  318.533061    172.099689790881  270.271411
#
# ...

# %%
df4["DEXRSA"].value_counts()
# Out:
# nan                   21
# 66.867495727982        1
# 82.45419792057601      1
# 82.237265947706        1
# 81.32629105730099      1
#                       ..
# 109.66103782456601     1
# 109.142066853937       1
# 108.849526785168       1
# 108.39036974905001     1
# 172.099689790881       1
# Name: DEXRSA, Length: 389, dtype: int64

# %%
df4.dtypes
# Out:
# DATE                  datetime64[ns]
# UNRATE                       float64
# CSUSHPISA                    float64
# SPCS10RSA                    float64
# DEXRSA                        object
# LVXRSA                       float64
# LXXRSA                       float64
# MIXRSA                       float64
# MNXRSA                        object
# NYXRSA                       float64
# PHXRSA                        object
# POXRSA                       float64
# SDXRSA                       float64
# SFXRSA                       float64
# PAYEMS                         int64
# INDPRO                       float64
# CSUSHPISA_20231031           float64
# CSUSHPISA_20231128           float64
# CPIAUCSL                     float64
# dtype: object

# %% [markdown]
# These are the data types of all columns present in the dataset,i.e.,datetime,float,int and object data type.

# %%
#converting object data type to float
df4["DEXRSA"]=df4["DEXRSA"].astype(float)
df4["MNXRSA"]=df4["MNXRSA"].astype(float)
df4["PHXRSA"]=df4["PHXRSA"].astype(float)
df4.dtypes
# Out:
# DATE                  datetime64[ns]
# UNRATE                       float64
# CSUSHPISA                    float64
# SPCS10RSA                    float64
# DEXRSA                       float64
# LVXRSA                       float64
# LXXRSA                       float64
# MIXRSA                       float64
# MNXRSA                       float64
# NYXRSA                       float64
# PHXRSA                       float64
# POXRSA                       float64
# SDXRSA                       float64
# SFXRSA                       float64
# PAYEMS                         int64
# INDPRO                       float64
# CSUSHPISA_20231031           float64
# CSUSHPISA_20231128           float64
# CPIAUCSL                     float64
# dtype: object

# %%
#we replace "." values using nan
df4["DEXRSA"]=df4["DEXRSA"].replace(".","nan")

# %%
df4
# Out:
#           DATE  UNRATE  CSUSHPISA   SPCS10RSA      DEXRSA      LVXRSA  \
# 0   1989-04-01     5.2     75.086   80.441948         NaN   69.997252
# 1   1989-05-01     5.2     75.306   80.831878         NaN   69.788148
# 2   1989-06-01     5.3     75.479   81.073507         NaN   71.554147
# 3   1989-07-01     5.2     75.657   81.139316         NaN   71.771789
# 4   1989-08-01     5.2     75.835   81.403008         NaN   72.390032
# ..         ...     ...        ...         ...         ...         ...
# 404 2022-12-01     3.5    297.413  314.634797  168.703020  276.602762
# 405 2023-01-01     3.4    297.030  314.093523  168.612725  273.921557
# 406 2023-02-01     3.6    297.537  314.426445  168.162693  271.856550
# 407 2023-03-01     3.5    298.637  315.906003  170.463590  270.568432
# 408 2023-04-01     3.4    300.213  318.533061  172.099690  270.271411
#
#          LXXRSA      MIXRSA      MNXRSA      NYXRSA      PHXRSA      POXRSA  \
# ...

# %%
#we fill null values using bfill
df4.bfill(axis=None, inplace=True, limit=None, downcast=None)
df4
# Out:
#           DATE  UNRATE  CSUSHPISA   SPCS10RSA      DEXRSA      LVXRSA  \
# 0   1989-04-01     5.2     75.086   80.441948   58.420806   69.997252
# 1   1989-05-01     5.2     75.306   80.831878   58.420806   69.788148
# 2   1989-06-01     5.3     75.479   81.073507   58.420806   71.554147
# 3   1989-07-01     5.2     75.657   81.139316   58.420806   71.771789
# 4   1989-08-01     5.2     75.835   81.403008   58.420806   72.390032
# ..         ...     ...        ...         ...         ...         ...
# 404 2022-12-01     3.5    297.413  314.634797  168.703020  276.602762
# 405 2023-01-01     3.4    297.030  314.093523  168.612725  273.921557
# 406 2023-02-01     3.6    297.537  314.426445  168.162693  271.856550
# 407 2023-03-01     3.5    298.637  315.906003  170.463590  270.568432
# 408 2023-04-01     3.4    300.213  318.533061  172.099690  270.271411
#
#          LXXRSA      MIXRSA      MNXRSA      NYXRSA      PHXRSA      POXRSA  \
# ...

# %%
df4.isnull().sum()
# Out:
# DATE                  0
# UNRATE                0
# CSUSHPISA             0
# SPCS10RSA             0
# DEXRSA                0
# LVXRSA                0
# LXXRSA                0
# MIXRSA                0
# MNXRSA                0
# NYXRSA                0
# PHXRSA                0
# POXRSA                0
# SDXRSA                0
# SFXRSA                0
# PAYEMS                0
# INDPRO                0
# CSUSHPISA_20231031    0
# CSUSHPISA_20231128    0
# CPIAUCSL              0
# dtype: int64

# %% [markdown]
# Now , we can see null values are not present in this dataset.

# %%
#we can see null values using heatmap.
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here,we can clearly see that there are no null values present in this dataset.

# %%
df4.columns
# Out:
# Index(['DATE', 'UNRATE', 'CSUSHPISA', 'SPCS10RSA', 'DEXRSA', 'LVXRSA',
#        'LXXRSA', 'MIXRSA', 'MNXRSA', 'NYXRSA', 'PHXRSA', 'POXRSA', 'SDXRSA',
#        'SFXRSA', 'PAYEMS', 'INDPRO', 'CSUSHPISA_20231031',
#        'CSUSHPISA_20231128', 'CPIAUCSL'],
#       dtype='object')

# %% [markdown]
# These are the columns we are taking in the data set.

# %%
df4.shape
# Out:
# (409, 19)

# %% [markdown]
# There are 409 rows and 19 columns present in the dataset.

# %%
df4.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicate rows present in the dataset.

# %%
Dataset Description:

# %% [markdown]
# DATE:The Date of the house price collected

# %% [markdown]
# UNRATE:unemployment rate on the certain date at which house price collected

# %% [markdown]
# CSUSHPISA:National home price index

# %% [markdown]
# SPCS10RSA:10 city Composite home price index

# %% [markdown]
# SFXRSA:San Francisco Home priceIndex

# %% [markdown]
# LXXRSA:Los Angeles Home price index

# %% [markdown]
# SEXRSA:Seattle Home Price index

# %% [markdown]
# SDXRSA:San Diego Home price Index

# %% [markdown]
# NYXRSA:Newyork Home price Index

# %% [markdown]
# PHXRSA:Phoenix Home price Index

# %% [markdown]
# MIXRSA:Miami Home price index

# %% [markdown]
# LVXRSA:Los vegas home price index

# %% [markdown]
# MNXRSA:Minneapolis home price index

# %% [markdown]
# PAYEMS:pay roll of the employees

# %% [markdown]
# INDPRO:industrial production ,how it influence the house price

# %% [markdown]
# CSUSHPISA_20231031:U.S. National Home price index vintage 31-10-2023

# %% [markdown]
# CSUSHPISA_20231128:U.S. National Home price index vintage 28-11-2023

# %% [markdown]
# CPIAUCSL:Consumer Price Index for All Urban Consumers for  All Items in U.S. City Average

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 409 entries, 0 to 408
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   DATE                409 non-null    datetime64[ns]
#  1   UNRATE              409 non-null    float64
#  2   CSUSHPISA           409 non-null    float64
#  3   SPCS10RSA           409 non-null    float64
#  4   DEXRSA              409 non-null    float64
#  5   LVXRSA              409 non-null    float64
#  6   LXXRSA              409 non-null    float64
#  7   MIXRSA              409 non-null    float64
#  8   MNXRSA              409 non-null    float64
#  9   NYXRSA              409 non-null    float64
#  10  PHXRSA              409 non-null    float64
#  11  POXRSA              409 non-null    float64
#  12  SDXRSA              409 non-null    float64
#  13  SFXRSA              409 non-null    float64
#  14  PAYEMS              409 non-null    int64
# ...

# %% [markdown]
# This gives the information about the names of columns,non null count,data type and its memory usage.

# %%
df4.head()
# Out:
#         DATE  UNRATE  CSUSHPISA  SPCS10RSA     DEXRSA     LVXRSA     LXXRSA  \
# 0 1989-04-01     5.2     75.086  80.441948  58.420806  69.997252  93.012292
# 1 1989-05-01     5.2     75.306  80.831878  58.420806  69.788148  94.569357
# 2 1989-06-01     5.3     75.479  81.073507  58.420806  71.554147  95.513465
# 3 1989-07-01     5.2     75.657  81.139316  58.420806  71.771789  96.252043
# 4 1989-08-01     5.2     75.835  81.403008  58.420806  72.390032  96.662389
#
#       MIXRSA     MNXRSA     NYXRSA     PHXRSA     POXRSA     SDXRSA  \
# 0  77.548665  63.083199  83.880871  67.965016  45.350052  75.805260
# 1  77.567305  63.184290  83.494249  68.068567  45.612780  77.050350
# 2  77.808340  63.742821  82.946585  67.695914  46.019388  78.136649
# 3  78.042409  63.556229  82.171286  67.340460  46.255814  79.030234
# 4  78.259921  63.798456  81.936148  66.947644  46.586600  80.095191
#
#       SFXRSA  PAYEMS   INDPRO  CSUSHPISA_20231031  CSUSHPISA_20231128  \
# ...

# %% [markdown]
# This gives the first five rows of the dataset.

# %%
df4.tail()
# Out:
#           DATE  UNRATE  CSUSHPISA   SPCS10RSA      DEXRSA      LVXRSA  \
# 404 2022-12-01     3.5    297.413  314.634797  168.703020  276.602762
# 405 2023-01-01     3.4    297.030  314.093523  168.612725  273.921557
# 406 2023-02-01     3.6    297.537  314.426445  168.162693  271.856550
# 407 2023-03-01     3.5    298.637  315.906003  170.463590  270.568432
# 408 2023-04-01     3.4    300.213  318.533061  172.099690  270.271411
#
#          LXXRSA      MIXRSA      MNXRSA      NYXRSA      PHXRSA      POXRSA  \
# 404  394.206077  401.095097  228.534522  273.310622  314.857560  320.333047
# 405  393.766142  402.103911  228.335314  273.505089  312.475846  318.247338
# 406  395.589945  401.707092  228.380703  273.337606  313.113632  317.298507
# 407  397.076266  402.630034  230.198192  275.537639  311.593061  317.732074
# 408  400.831118  403.453187  231.304205  278.304896  311.053396  319.965528
#
#          SDXRSA      SFXRSA  PAYEMS    INDPRO  CSUSHPISA_20231031  \
# ...

# %% [markdown]
# This gives the last five rows of the dataset.

# %%
df4["CSUSHPISA"].nunique()
# Out:
# 408

# %%
df4["CSUSHPISA"].value_counts()
# Out:
# 76.056     2
# 75.086     1
# 137.952    1
# 142.279    1
# 141.669    1
#           ..
# 105.054    1
# 104.424    1
# 103.678    1
# 102.922    1
# 300.213    1
# Name: CSUSHPISA, Length: 408, dtype: int64

# %% [markdown]
# These are the unique values present in target column CSUSHPISA

# %%
#Description of Dataset.
df4.describe()
# Out:
#            UNRATE   CSUSHPISA   SPCS10RSA      DEXRSA      LVXRSA      LXXRSA  \
# count  409.000000  409.000000  409.000000  409.000000  409.000000  409.000000
# mean     5.793888  144.685888  157.673348   97.938996  138.087966  182.093336
# std      1.723593   57.857287   67.246857   28.863954   57.470647   90.520074
# min      3.400000   75.086000   75.810511   58.132123   69.788148   73.843781
# 25%      4.600000   86.147000   82.684299   71.203759   91.626513   95.513465
# 50%      5.400000  143.600000  156.880175   97.021856  115.003973  170.757063
# 75%      6.700000  179.680000  208.999154  118.654429  182.290572  252.105202
# max     14.700000  304.724000  326.541490  172.099690  296.345961  417.753567
#
#            MIXRSA      MNXRSA      NYXRSA      PHXRSA      POXRSA      SDXRSA  \
# count  409.000000  409.000000  409.000000  409.000000  409.000000  409.000000
# mean   167.407512  127.687447  151.045568  136.977233  146.650198  171.945942
# ...

# %% [markdown]
# This gives the statistical summary of the numerical columns.The summary of the dataset looks perfect since there is no negative/invalid values present.

# %% [markdown]
# From the above Description we can observe the following:

# %% [markdown]
# The counts of all the columns are same which means there are no missing values present in the dataset.

# %% [markdown]
# The mean is greater than the median in UNRATE,CSUSHPISA,SPCS10RSA,DEXRSA,LVXRSA,LXXRSA,MIXRSA,MNXRSA,PHXRSA,POXRSA,SDXRSA,SFXRSA,CSUSHPISA_20231031,CSUSHPISA_20231128 Columns which means the data is skewed to right in these columns.

# %% [markdown]
# The mean is less than the median in NYXRSA,PAYEMS,INDPRO,CPIAUCSL Columns which means the data is skewed to left in these columns.

# %% [markdown]
# By summarizing the data we can observe there is a huge differences between 75% and max,hence there are outliers present in the data.

# %% [markdown]
# we can  also notice the standard deviation ,min 25%  percentile values from this describe method.

# %%
#we can visualize the description using heatmap.
plt.figure(figsize=(20,10))
sns.heatmap(df.describe(),annot=True,fmt=".02f",linewidth=0.2,linecolor="black",cmap="Spectral")
plt.xlabel("Figure",fontsize=14)
plt.ylabel("Features_Name",fontsize=14)
plt.title("Description of Dataset",fontsize=20)
plt.show()

# %% [markdown]
# Data Visualization:

# %%
sns.lmplot(x="UNRATE",y="CSUSHPISA",data=df4,palette="icefire")

# %% [markdown]
# unemployment rate has a negative correlation with target column national house price index

# %%
df4.columns
# Out:
# Index(['DATE', 'UNRATE', 'CSUSHPISA', 'SPCS10RSA', 'DEXRSA', 'LVXRSA',
#        'LXXRSA', 'MIXRSA', 'MNXRSA', 'NYXRSA', 'PHXRSA', 'POXRSA', 'SDXRSA',
#        'SFXRSA', 'PAYEMS', 'INDPRO', 'CSUSHPISA_20231031',
#        'CSUSHPISA_20231128', 'CPIAUCSL'],
#       dtype='object')

# %%
sns.lmplot(x="SPCS10RSA",y="CSUSHPISA",data=df4,palette="icefire")

# %% [markdown]
# SPCS10RSA has a positive relation with CSUSHPISA

# %%
sns.lmplot(x="DEXRSA",y="CSUSHPISA",data=df4,palette="icefire")

# %% [markdown]
# DEXRSA has a positive relation with CSUSHPISA

# %%
sns.lmplot(x="LVXRSA",y="CSUSHPISA",data=df4,palette="icefire")

# %% [markdown]
#  LVXRSA has a positive relation with CSUSHPISA

# %%
sns.lmplot(x="LXXRSA",y="CSUSHPISA",data=df4,palette="icefire")

# %% [markdown]
# LXXRSA has a positive relation with CSUSHPISA

# %%
sns.lmplot(x="MIXRSA",y="CSUSHPISA",data=df4,palette="icefire")

# %% [markdown]
# MIXRSA has a positive relation with CSUSHPISA

# %%
sns.lmplot(x="MNXRSA",y="CSUSHPISA",data=df4,palette="icefire")

# %% [markdown]
# MNXRSA has a positive relation with CSUSHPISA

# %%
sns.lmplot(x="NYXRSA",y="CSUSHPISA",data=df4,palette="icefire")

# %% [markdown]
# NYXRSA has a positive relation with CSUSHPISA

# %%
sns.lmplot(x="PHXRSA",y="CSUSHPISA",data=df4,palette="icefire")

# %% [markdown]
# PHXRSA has a positive relation with CSUSHPISA

# %%
sns.lmplot(x="POXRSA",y="CSUSHPISA",data=df4,palette="icefire")

# %% [markdown]
# POXRSA has a positive relation with CSUSHPISA

# %%
sns.lmplot(x="SDXRSA",y="CSUSHPISA",data=df4,palette="icefire")

# %% [markdown]
# SDXRSA has a positive relation with CSUSHPISA

# %%
sns.lmplot(x="SFXRSA",y="CSUSHPISA",data=df4,palette="icefire")

# %% [markdown]
# SFXRSA has a positive relation with CSUSHPISA

# %%
sns.lmplot(x="PAYEMS",y="CSUSHPISA",data=df4,palette="icefire")

# %% [markdown]
# PAYEMS has a positive relation with CSUSHPISA

# %%
sns.lmplot(x="INDPRO",y="CSUSHPISA",data=df4,palette="icefire")

# %% [markdown]
# INDPRO  has a positive relation with CSUSHPISA

# %%
sns.lmplot(x="CSUSHPISA_20231031",y="CSUSHPISA",data=df4,palette="icefire")

# %% [markdown]
# CSUSHPISA_20231031 has a positive relation with CSUSHPISA

# %%
sns.lmplot(x="CSUSHPISA_20231128",y="CSUSHPISA",data=df4,palette="icefire")

# %% [markdown]
# CSUSHPISA_20231128  has a positive relation with CSUSHPISA

# %%
sns.lmplot(x="CPIAUCSL",y="CSUSHPISA",data=df4,palette="icefire")

# %% [markdown]
# CPIAUCSL  has a positive relation with CSUSHPISA

# %% [markdown]
# All columns have a positive relation with target column CSUSHPISA except UNRATE Column

# %%
sns.pairplot(data=df4,palette="icefire")

# %% [markdown]
# This pairplot gives the relation between the features. On the diagonal we can notice the distribution plots.

# %% [markdown]
# Let's check the outliers by plotting boxplot for all the columns

# %%
sns.boxplot(x="UNRATE",data=df4,palette="Accent")
# Out:
# <AxesSubplot:xlabel='UNRATE'>

# %%
sns.boxplot(x="CSUSHPISA",data=df4,palette="Accent")
# Out:
# <AxesSubplot:xlabel='CSUSHPISA'>

# %%
sns.boxplot(x="SPCS10RSA",data=df4,palette="Accent")
# Out:
# <AxesSubplot:xlabel='SPCS10RSA'>

# %%
sns.boxplot(x="DEXRSA",data=df4,palette="Accent")
# Out:
# <AxesSubplot:xlabel='DEXRSA'>

# %%
sns.boxplot(x="LVXRSA",data=df4,palette="Accent")
# Out:
# <AxesSubplot:xlabel='LVXRSA'>

# %%
sns.boxplot(x="LXXRSA",data=df4,palette="Accent")
# Out:
# <AxesSubplot:xlabel='LXXRSA'>

# %%
sns.boxplot(x="MIXRSA",data=df4,palette="Accent")
# Out:
# <AxesSubplot:xlabel='MIXRSA'>

# %%
sns.boxplot(x="MNXRSA",data=df4,palette="Accent")
# Out:
# <AxesSubplot:xlabel='MNXRSA'>

# %%
sns.boxplot(x="NYXRSA",data=df4,palette="Accent")
# Out:
# <AxesSubplot:xlabel='NYXRSA'>

# %%
sns.boxplot(x="NYXRSA",data=df4,palette="Accent")
# Out:
# <AxesSubplot:xlabel='NYXRSA'>

# %%
sns.boxplot(x="PHXRSA",data=df4,palette="Accent")
# Out:
# <AxesSubplot:xlabel='PHXRSA'>

# %%
sns.boxplot(x="POXRSA",data=df4,palette="Accent")
# Out:
# <AxesSubplot:xlabel='POXRSA'>

# %%
sns.boxplot(x="SDXRSA",data=df4,palette="Accent")
# Out:
# <AxesSubplot:xlabel='SDXRSA'>

# %%
sns.boxplot(x="SFXRSA",data=df4,palette="Accent")
# Out:
# <AxesSubplot:xlabel='SFXRSA'>

# %%
sns.boxplot(x="PAYEMS",data=df4,palette="Accent")
# Out:
# <AxesSubplot:xlabel='PAYEMS'>

# %%
sns.boxplot(x="INDPRO",data=df4,palette="Accent")
# Out:
# <AxesSubplot:xlabel='INDPRO'>

# %%
sns.boxplot(x="CSUSHPISA_20231031",data=df4,palette="Accent")
# Out:
# <AxesSubplot:xlabel='CSUSHPISA_20231031'>

# %%
sns.boxplot(x="CSUSHPISA_20231128",data=df4,palette="Accent")
# Out:
# <AxesSubplot:xlabel='CSUSHPISA_20231128'>

# %%
sns.boxplot(x="CPIAUCSL",data=df4,palette="Accent")
# Out:
# <AxesSubplot:xlabel='CPIAUCSL'>

# %% [markdown]
# outliers are present in UNRATE,POXRSA,PHXRSA Columns.we will remove the outliers using score technique.

# %%
#let us observe the skewness in all the columns by plotting distribution plots
plt.figure(figsize=(10,10),facecolor="blue")
plotnumber=1
x=df4[["UNRATE","CSUSHPISA","SPCS10RSA","DEXRSA","LVXRSA","LXXRSA","MIXRSA","MNXRSA","NYXRSA","PHXRSA","POXRSA","SDXRSA","SFXRSA","PAYEMS","INDPRO","CSUSHPISA_20231031",
       "CSUSHPISA_20231128","CPIAUCSL"]]
for column in x:
    if plotnumber<=18:
        ax=plt.subplot(6,3,plotnumber)
        sns.distplot(x,color="m")
        plt.xlabel(column,fontsize=10)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
    plt.tight_layout()

# %% [markdown]
# from the above distribution plots, we can notice that the data almost looks normal in all the columns except UNRATE column.

# %%
from scipy.stats import zscore
x=df4[["UNRATE","CSUSHPISA","SPCS10RSA","DEXRSA","LVXRSA","LXXRSA","MIXRSA","MNXRSA","NYXRSA","PHXRSA","POXRSA","SDXRSA","SFXRSA","PAYEMS","INDPRO","CSUSHPISA_20231031",
       "CSUSHPISA_20231128","CPIAUCSL"]]
z=np.abs(x)
z
# Out:
#      UNRATE  CSUSHPISA   SPCS10RSA      DEXRSA      LVXRSA      LXXRSA  \
# 0       5.2     75.086   80.441948   58.420806   69.997252   93.012292
# 1       5.2     75.306   80.831878   58.420806   69.788148   94.569357
# 2       5.3     75.479   81.073507   58.420806   71.554147   95.513465
# 3       5.2     75.657   81.139316   58.420806   71.771789   96.252043
# 4       5.2     75.835   81.403008   58.420806   72.390032   96.662389
# ..      ...        ...         ...         ...         ...         ...
# 404     3.5    297.413  314.634797  168.703020  276.602762  394.206077
# 405     3.4    297.030  314.093523  168.612725  273.921557  393.766142
# 406     3.6    297.537  314.426445  168.162693  271.856550  395.589945
# 407     3.5    298.637  315.906003  170.463590  270.568432  397.076266
# 408     3.4    300.213  318.533061  172.099690  270.271411  400.831118
#
#          MIXRSA      MNXRSA      NYXRSA      PHXRSA      POXRSA      SDXRSA  \
# ...

# %%
#threshold=3
np.where(z>3)
# Out:
# (array([  0,   0,   0, ..., 408, 408, 408], dtype=int64),
#  array([ 0,  1,  2, ..., 15, 16, 17], dtype=int64))

# %%
df5=df4[(z>3).all(axis=1)]
df5
df5.shape
# Out:
# (409, 19)

# %%
df4.shape
# Out:
# (409, 19)

# %%
print("Data loss percentage",((df4.shape[0]-df5.shape[0])/df4.shape[0])*100)
# Out:
# Data loss percentage 0.0

# %%
#checking for skewness
df4.skew()
# Out:
# UNRATE                1.246218
# CSUSHPISA             0.739933
# SPCS10RSA             0.435221
# DEXRSA                0.495962
# LVXRSA                0.937617
# LXXRSA                0.599241
# MIXRSA                0.905133
# MNXRSA                0.299428
# NYXRSA                0.061796
# PHXRSA                1.156466
# POXRSA                0.806131
# SDXRSA                0.760801
# SFXRSA                0.701267
# PAYEMS               -0.306287
# INDPRO               -0.913717
# CSUSHPISA_20231031    0.739894
# CSUSHPISA_20231128    0.739933
# CPIAUCSL              0.166685
# dtype: float64

# %% [markdown]
# skewness is present in UNRATE,CSUSHPISA,LVXRSA,MIXRSA,PHXRSA,POXRSA,SDXRSA,SFXRSA,INDPRO,CSUSHPISA_20231031,CSUSHPISA_20231128 Columns.Let us remove skewness using cuberoot method and no need to remove skewness in target CSUSHPISA Variable.

# %%
df4["UNRATE"]=np.cbrt(df4["UNRATE"])
df4["LVXRSA"]=np.cbrt(df4["LVXRSA"])
df4["MIXRSA"]=np.cbrt(df4["MIXRSA"])
df4["PHXRSA"]=np.cbrt(df4["PHXRSA"])
df4["POXRSA"]=np.cbrt(df4["POXRSA"])
df4["SDXRSA"]=np.cbrt(df4["SDXRSA"])
df4["SFXRSA"]=np.cbrt(df4["SFXRSA"])
df4["INDPRO"]=np.cbrt(df4["INDPRO"])
df4["CSUSHPISA_20231031"]=np.cbrt(df4["CSUSHPISA_20231031"])
df4["CSUSHPISA_20231128"]=np.cbrt(df4["CSUSHPISA_20231128"])

# %%
df4.skew()
# Out:
# UNRATE                0.716658
# CSUSHPISA             0.739933
# SPCS10RSA             0.435221
# DEXRSA                0.495962
# LVXRSA                0.630730
# LXXRSA                0.599241
# MIXRSA                0.368735
# MNXRSA                0.299428
# NYXRSA                0.061796
# PHXRSA                0.569373
# POXRSA                0.182569
# SDXRSA                0.188666
# SFXRSA                0.196216
# PAYEMS               -0.306287
# INDPRO               -1.015726
# CSUSHPISA_20231031    0.234058
# CSUSHPISA_20231128    0.234077
# CPIAUCSL              0.166685
# dtype: float64

# %% [markdown]
# still some skewness is present in UNRATE,INDPRO Columns.

# %%
#Now we will check the correlation between features and target variable
df4.corr()
# Out:
#                       UNRATE  CSUSHPISA  SPCS10RSA    DEXRSA    LVXRSA  \
# UNRATE              1.000000  -0.265113  -0.258863 -0.542865 -0.421173
# CSUSHPISA          -0.265113   1.000000   0.991613  0.854451  0.913031
# SPCS10RSA          -0.258863   0.991613   1.000000  0.851497  0.935369
# DEXRSA             -0.542865   0.854451   0.851497  1.000000  0.909036
# LVXRSA             -0.421173   0.913031   0.935369  0.909036  1.000000
# LXXRSA             -0.275606   0.987645   0.993926  0.835235  0.928715
# MIXRSA             -0.295566   0.975653   0.992171  0.859265  0.958288
# MNXRSA             -0.314008   0.971979   0.980536  0.922787  0.950113
# NYXRSA             -0.162923   0.965739   0.982856  0.794110  0.905759
# PHXRSA             -0.377306   0.968063   0.976509  0.908428  0.968480
# POXRSA             -0.256337   0.971492   0.960708  0.825607  0.872931
# SDXRSA             -0.242643   0.975857   0.992954  0.855622  0.928202
# ...

# %% [markdown]
# This gives the correlation between dependent and independent variables.

# %%
df4.corr().CSUSHPISA.sort_values()
# Out:
# UNRATE               -0.265113
# INDPRO                0.778345
# DEXRSA                0.854451
# PAYEMS                0.895857
# LVXRSA                0.913031
# CPIAUCSL              0.938489
# NYXRSA                0.965739
# PHXRSA                0.968063
# POXRSA                0.971492
# MNXRSA                0.971979
# SFXRSA                0.972513
# MIXRSA                0.975653
# SDXRSA                0.975857
# LXXRSA                0.987645
# CSUSHPISA_20231031    0.989798
# CSUSHPISA_20231128    0.989799
# SPCS10RSA             0.991613
# CSUSHPISA             1.000000
# Name: CSUSHPISA, dtype: float64

# %% [markdown]
# we can observe all the features have positive correlation with target column except UNRATE column.

# %%
#visualizing the correlation between label and features using bar plot
plt.figure(figsize=(20,10))
df4.corr()["CSUSHPISA"].sort_values(ascending=False).drop(["CSUSHPISA"]).plot(kind="bar",color="m")
plt.xlabel("Features",fontsize=15)
plt.ylabel("Target",fontsize=15)
plt.title("Correlation between features and target using bar plot",fontsize=20)
plt.show()

# %% [markdown]
# From the above bar plot we can conclude that all the features have positive correlation with the target except UNRATE column.

# %%
#Seperating features and label:
x=df4.drop("CSUSHPISA",axis=1)
y=df4["CSUSHPISA"]

# %%
x.shape
# Out:
# (409, 18)

# %%
y.shape
# Out:
# (409,)

# %%
x.drop("DATE",axis=1,inplace=True)

# %% [markdown]
# Feature scaling using StandardScaler:

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
X
# Out:
#        UNRATE  SPCS10RSA    DEXRSA    LVXRSA    LXXRSA    MIXRSA    MNXRSA  \
# 0   -0.285917  -1.149883 -1.370796 -1.423549 -0.985308 -1.294177 -1.432985
# 1   -0.285917  -1.144077 -1.370796 -1.429656 -0.968086 -1.293779 -1.430743
# 2   -0.219813  -1.140479 -1.370796 -1.378457 -0.957643 -1.288638 -1.418354
# 3   -0.285917  -1.139500 -1.370796 -1.372206 -0.949474 -1.283655 -1.422493
# 4   -0.285917  -1.135574 -1.370796 -1.354517 -0.944935 -1.279033 -1.417120
# ..        ...        ...       ...       ...       ...       ...       ...
# 404 -1.568936   2.336967  2.454643  2.135979  2.346137  2.329944  2.236886
# 405 -1.656393   2.328908  2.451510  2.104580  2.341271  2.337142  2.232467
# 406 -1.483129   2.333865  2.435900  2.080257  2.361444  2.334312  2.233474
# 407 -1.568936   2.355894  2.515713  2.065022  2.377884  2.340892  2.273788
# 408 -1.656393   2.395007  2.572465  2.061502  2.419416  2.346751  2.298320
#
# ...

# %% [markdown]
# we have scaled the data using standard scalarization method to overcome the issue of biasness.

# %%
#Checking Variance Inflation Factor(VIF)
#Finding variance inflation factor in each scaled column.
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
vif["features"]=X.columns
vif
# Out:
#       VIF values            features
# 0   3.499146e+01              UNRATE
# 1   1.363538e+04           SPCS10RSA
# 2   1.720006e+02              DEXRSA
# 3   9.662850e+01              LVXRSA
# 4   2.175984e+03              LXXRSA
# 5   3.976480e+02              MIXRSA
# 6   5.854407e+02              MNXRSA
# 7   2.761692e+03              NYXRSA
# 8   3.285505e+02              PHXRSA
# 9   3.217181e+02              POXRSA
# 10  1.238349e+03              SDXRSA
# 11  4.933137e+02              SFXRSA
# 12  4.878495e+02              PAYEMS
# 13  1.024682e+02              INDPRO
# 14  2.523922e+07  CSUSHPISA_20231031
# 15  2.527608e+07  CSUSHPISA_20231128
# 16  4.720796e+02            CPIAUCSL

# %% [markdown]
# By checking the vif value,multi collinearity not exists.we can now move ahead for model building.

# %% [markdown]
# Modelling:

# %%
#import necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
#creating train test split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=200)

# %%
from sklearn import metrics

# %%
def r2_score(name,x_train,x_test,y_train,y_test,train=True):
    if train:
        y_pred=name.predict(x_train)
        print("r2_score on training data",metrics.r2_score(y_train,y_pred)*100)
        
    else:
         if train==False:
            y_test_pred=name.predict(x_test)
            print("r2_score:",metrics.r2_score(y_test,y_test_pred))
            print("Mean absolute error:-",mean_absolute_error(y_test,y_test_pred))
            print("mean squared error:-",mean_squared_error(y_test,y_test_pred))
            print("Root mean squared error:-",np.sqrt(mean_squared_error(y_test,y_test_pred)))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
#Model initiation for LinearRegression
name=LinearRegression()
name.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
r2_score(name,x_train,x_test,y_train,y_test,train=True)
r2_score(name,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data 99.97377612735305
# r2_score: 0.9996955843893004
# Mean absolute error:- 0.7454257875244432
# mean squared error:- 0.9267772607537031
# Root mean squared error:- 0.9626927135663296

# %% [markdown]
# r2_score using linear regression is 99.69%

# %%
#finding the random state
maxAccuracy=0
maxRs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=i)
    name=LinearRegression()
    name.fit(x_train,y_train)
    y_test_pred=name.predict(x_test)
    acc=metrics.r2_score(y_test,y_test_pred)
    if acc>maxAccuracy:
        maxAccuracy=acc
        maxRs=i
print("maximum r2_score is ",maxAccuracy,"on Random state",maxRs)
# Out:
# maximum r2_score is  0.9997914058781485 on Random state 144

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score=cross_val_score(name,X,y)
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score.mean())*100)
# Out:
# [-19.23298156   0.92769692   0.94259702   0.78633697   0.84043485]
# -3.1471831606895244
# Difference between R2 score and cross validation score is : 414.6926000565645

# %%
#Model initiation for RandomForestRegressor
name1=RandomForestRegressor()
name1.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
r2_score(name1,x_train,x_test,y_train,y_test,train=True)
r2_score(name1,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data 99.99739240182916
# r2_score: 0.9998729636444503
# Mean absolute error:- 0.3965955284553019
# mean squared error:- 0.4614765355130517
# Root mean squared error:- 0.6793206426372245

# %% [markdown]
# r2_score using Random forest regressor is 99.98%

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score1=cross_val_score(name1,X,y)
print(score1)
print(score1.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score1.mean())*100)
# Out:
# [-9.10453698  0.88231712  0.92918393  0.95290206 -1.36337825]
# -1.5407024248213284
# Difference between R2 score and cross validation score is : 254.04452646974488

# %%
#Model initiation for KNN
name2=KNN()
name2.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
r2_score(name2,x_train,x_test,y_train,y_test,train=True)
r2_score(name2,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data 99.94686041540413
# r2_score: 0.999412183808727
# Mean absolute error:- 0.8735577235772336
# mean squared error:- 2.1353208559349515
# Root mean squared error:- 1.4612737101361097

# %% [markdown]
# r2_score using knn is 99.94%

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score2=cross_val_score(name2,X,y)
print(score2)
print(score2.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score2.mean())*100)
# Out:
# [-6.19172972  0.05597533  0.70800449  0.78632326 -1.42655881]
# -1.2135970897332657
# Difference between R2 score and cross validation score is : 221.33399296093864

# %%
#Model initiation for GradientBoostingRegressor
name3=GradientBoostingRegressor()
name3.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
r2_score(name3,x_train,x_test,y_train,y_test,train=True)
r2_score(name3,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data 99.9986210614735
# r2_score: 0.9996046318260995
# Mean absolute error:- 0.6876829590846592
# mean squared error:- 1.4362277188627675
# Root mean squared error:- 1.198427185465503

# %% [markdown]
# r2_score using Gradient Boosting Regressor is 99.96%

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score3=cross_val_score(name3,X,y)
print(score3)
print(score3.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score3.mean())*100)
# Out:
# [-6.28213141  0.77391903  0.64812595  0.98249991 -1.33542382]
# -1.0426020686494362
# Difference between R2 score and cross validation score is : 204.2344908525557

# %%
#Model initiation for Lasso
name4=Lasso()
name4.fit(x_train,y_train)
# Out:
# Lasso()

# %%
r2_score(name4,x_train,x_test,y_train,y_test,train=True)
r2_score(name4,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data 99.08637432091496
# r2_score: 0.9906370371739873
# Mean absolute error:- 3.815620072882008
# mean squared error:- 34.0122134989714
# Root mean squared error:- 5.831999099705984

# %% [markdown]
# r2_score using Lasso is 99.06%

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score4=cross_val_score(name4,X,y)
print(score4)
print(score4.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score4.mean())*100)
# Out:
# [-53.26052156   0.98992932  -0.08486991   0.42208563   0.25024386]
# -10.336626529416765
# Difference between R2 score and cross validation score is : 1133.6369369292886

# %%
#Model initiation for Ridge
name5=Ridge()
name5.fit(x_train,y_train)
# Out:
# Ridge()

# %%
r2_score(name5,x_train,x_test,y_train,y_test,train=True)
r2_score(name5,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data 99.9305600043393
# r2_score: 0.9993731763797208
# Mean absolute error:- 1.1726616459696464
# mean squared error:- 2.277020553782687
# Root mean squared error:- 1.5089799712993832

# %% [markdown]
# r2_score using Ridge is 99.93%

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score5=cross_val_score(name5,X,y)
print(score5)
print(score5.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score5.mean())*100)
# Out:
# [-6.49607523  0.87771372  0.25003381  0.98744214  0.70778836]
# -0.7346194389911493
# Difference between R2 score and cross validation score is : 173.436227886727

# %%
#Model initiation for DecisionTreeRegressor
name6=DecisionTreeRegressor()
name6.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
r2_score(name6,x_train,x_test,y_train,y_test,train=True)
r2_score(name6,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data 100.0
# r2_score: 0.9993275713139339
# Mean absolute error:- 0.9238617886178869
# mean squared error:- 2.4426870487804937
# Root mean squared error:- 1.5629098018697347

# %% [markdown]
# r2 score using Decision tree regressor is 99.93%

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score6=cross_val_score(name6,X,y)
print(score6)
print(score6.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score6.mean())*100)
# Out:
# [-22.90017551  -0.33866992   0.40304493   0.88014406  -1.32835477]
# -4.6568022436426
# Difference between R2 score and cross validation score is : 565.6545083518721

# %%
from sklearn.svm import SVR
#Model initiation for SVR
name7=SVR()
name7.fit(x_train,y_train)
# Out:
# SVR()

# %%
r2_score(name7,x_train,x_test,y_train,y_test,train=True)
r2_score(name7,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data 71.61499100826767
# r2_score: 0.6706425570834031
# Mean absolute error:- 14.4208090302307
# mean squared error:- 1196.4349185315725
# Root mean squared error:- 34.58952035706151

# %% [markdown]
# r2 score using SVR is 67%

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score7=cross_val_score(name7,X,y)
print(score7)
print(score7.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score7.mean())*100)
# Out:
# [-636.97068293    0.72069765    0.94939576    0.97671704   -4.8666504 ]
# -127.83810457354184
# Difference between R2 score and cross validation score is : 12883.784741341797

# %%
from sklearn.ensemble import ExtraTreesRegressor
#Model initiation for ExtraTreesRegressor
name8=ExtraTreesRegressor()
name8.fit(x_train,y_train)
# Out:
# ExtraTreesRegressor()

# %%
r2_score(name8,x_train,x_test,y_train,y_test,train=True)
r2_score(name8,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data 100.0
# r2_score: 0.9999679669848051
# Mean absolute error:- 0.186003333333341
# mean squared error:- 0.11636420779106614
# Root mean squared error:- 0.3411219837405179

# %% [markdown]
# r2_score using Extra trees regressor is 99.99%

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score8=cross_val_score(name8,X,y)
print(score8)
print(score8.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score8.mean())*100)
# Out:
# [-10.38478285   0.96473838   0.66832068   0.99719293  -1.35363904]
# -1.821633979433777
# Difference between R2 score and cross validation score is : 282.13768193098974

# %% [markdown]
# we can observe from the difference of both r2_score and cv_score computed on R2_score we can conclude that Ridge Regression as our best fitting and best performing model.

# %% [markdown]
# Hyper Parameter Tuning:

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={"alpha":[1.0,.05],
           "solver":['auto','svd','cholesky'],
           'positive':[False,True],
           'random_state':[1,4,10,20]}

# %%
gsv=GridSearchCV(Ridge(),parameters,cv=5)

# %%
gsv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1.0, 0.05], 'positive': [False, True],
#                          'random_state': [1, 4, 10, 20],
#                          'solver': ['auto', 'svd', 'cholesky']})

# %%
gsv.best_params_
# Out:
# {'alpha': 0.05, 'positive': False, 'random_state': 1, 'solver': 'auto'}

# %%
Model=Ridge(alpha=0.05,positive=False,random_state=1,solver='auto')

# %%
Model.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.05, random_state=1)

# %%
pred=Model.predict(x_test)
pred
# Out:
# array([ 76.30204313, 258.51503457, 140.68204556, 163.5689242 ,
#        181.92801675,  75.55173539, 183.85865077, 281.69824082,
#        165.49027964, 147.61098363,  86.26274784, 164.19220295,
#        296.3336085 , 162.73908632,  77.42484746, 189.75131497,
#         90.94865077,  75.13492076,  82.19114723, 141.64441825,
#         86.26451577, 116.32273602, 148.17443486,  74.9936906 ,
#        143.13835281, 171.76129474, 139.74980809,  80.29324387,
#         84.72371454,  79.86920854, 149.08209033, 118.35249027,
#        147.71817399, 168.85140861, 263.10443596, 214.74635179,
#         74.51166567, 231.49396012,  85.41080749,  77.31764748,
#        211.69137894, 108.04573521, 147.00436706, 212.71493656,
#        217.85750296, 180.84168162, 148.17505507, 173.78313861,
#        201.30734197, 298.57089959,  75.48090437,  75.5799796 ,
#        273.58005192,  81.4060361 , 185.37897266,  75.71602145,
#        138.38266896, 141.50694858, 132.92054704, 172.83206391,
# ...

# %%
print("R2_score:",metrics.r2_score(y_test,pred))
print("Mean Absolute error:",mean_absolute_error(y_test,pred))
print("mean squared error:",mean_squared_error(y_test,pred))
print("Root mean squared error:",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.9996942467038685
# Mean Absolute error: 0.8440942353184485
# mean squared error: 1.1106897014633366
# Root mean squared error: 1.0538926422854165

# %% [markdown]
# r2_score for Ridge regression using Hyper parameter tuning is 84.40%

# %%
import pickle     #to save the model
file_name="HomeLLC__Project.pkl"
pickle.dump(Model,open(file_name,'wb'))

# %%
import pickle #to load the model
loaded_model=pickle.load(open("HomeLLC__Project.pkl",'rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 99.96942467038686

# %% [markdown]
# r2_ score for the loaded model is 99.96%

# %%
pred=Model.predict(x_test)
pred
# Out:
# array([ 76.30204313, 258.51503457, 140.68204556, 163.5689242 ,
#        181.92801675,  75.55173539, 183.85865077, 281.69824082,
#        165.49027964, 147.61098363,  86.26274784, 164.19220295,
#        296.3336085 , 162.73908632,  77.42484746, 189.75131497,
#         90.94865077,  75.13492076,  82.19114723, 141.64441825,
#         86.26451577, 116.32273602, 148.17443486,  74.9936906 ,
#        143.13835281, 171.76129474, 139.74980809,  80.29324387,
#         84.72371454,  79.86920854, 149.08209033, 118.35249027,
#        147.71817399, 168.85140861, 263.10443596, 214.74635179,
#         74.51166567, 231.49396012,  85.41080749,  77.31764748,
#        211.69137894, 108.04573521, 147.00436706, 212.71493656,
#        217.85750296, 180.84168162, 148.17505507, 173.78313861,
#        201.30734197, 298.57089959,  75.48090437,  75.5799796 ,
#        273.58005192,  81.4060361 , 185.37897266,  75.71602145,
#        138.38266896, 141.50694858, 132.92054704, 172.83206391,
# ...

# %%
G=np.array(y_test)
df6=pd.DataFrame()
df6['predicted']=pred
df6["original"]=G
df6
# Out:
#       predicted  original
# 0     76.302043    76.837
# 1    258.515035   258.358
# 2    140.682046   141.521
# 3    163.568924   161.927
# 4    181.928017   183.010
# ..          ...       ...
# 118   99.972072   100.551
# 119  148.931143   148.186
# 120  296.337453   298.873
# 121  153.972805   154.199
# 122  199.952118   198.315
#
# [123 rows x 2 columns]

# %% [markdown]
# predicted is the  national house price index
