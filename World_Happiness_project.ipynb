# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Project Description:

# %% [markdown]
# The World Happiness Report is a landmark survey of the state of global happiness. The first report was published in 2012, the second in 2013, the third in 2015, and the fourth in the 2016 Update. The World Happiness 2017, which ranks 155 countries by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March 20th. The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions.

# %% [markdown]
# . Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.

# %% [markdown]
#  GDP per Capita, Family, Life Expectancy, Freedom, Generosity, Trust Government Corruption describe the extent to which these factors contribute in evaluating the happiness in each country.

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv")
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# Exploratory Data Analysis(EDA):

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
#checking the dimension of dataset.
df.shape
# Out:
# (158, 12)

# %% [markdown]
# This dataset has 158 rows and 12 columns.

# %%
#checking the columns of dataset.
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# These are the columns of the given dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# this gives the brief description about the dataset: non null values count,data type and memory usage.

# %%
#checking the unique values in all columns of the given dataset.
df.nunique()
# Out:
# Country                          158
# Region                            10
# Happiness Rank                   157
# Happiness Score                  157
# Standard Error                   153
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         157
# Freedom                          158
# Trust (Government Corruption)    157
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %% [markdown]
# These are the unique values of each column.

# %%
#checking the duplicate values in the dataset.
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicate rows in the dataset.

# %%
#checking the null values in the dataset.
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# There are no null values present in the dataset.

# %% [markdown]
# we can also check the null values using heatmap.

# %%
#Checking the null values using heatmap.
sns.heatmap(df.isnull(),color="red")
# Out:
# <AxesSubplot:>

# %% [markdown]
# we can observe that there are no null values in the given dataset.

# %%
#checking the data types of the columns.
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# There are three  different types of data present in the dataset:float64,int64 and object

# %%
#checking the value counts of each column.
for i in df.columns:
    print(df[i].value_counts())
# Out:
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: Happiness Rank, Length: 157, dtype: int64
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# 2.839    1
# ...

# %% [markdown]
# These are the value counts of all the columns.

# %%
df['Standard Error'].unique
# Out:
# <bound method Series.unique of 0      0.03411
# 1      0.04884
# 2      0.03328
# 3      0.03880
# 4      0.03553
#         ...
# 153    0.03464
# 154    0.03656
# 155    0.05015
# 156    0.08658
# 157    0.06727
# Name: Standard Error, Length: 158, dtype: float64>

# %% [markdown]
# Encoding Categorical columns:

# %%
#Encoding categorical columns using ordinal Encoder
from sklearn.preprocessing import OrdinalEncoder
OE=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=OE.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135.0     9.0               1            7.587         0.03411
# 1       58.0     9.0               2            7.561         0.04884
# 2       37.0     9.0               3            7.527         0.03328
# 3      105.0     9.0               4            7.522         0.03880
# 4       24.0     5.0               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153    118.0     8.0             154            3.465         0.03464
# 154     13.0     8.0             155            3.340         0.03656
# 155    136.0     4.0             156            3.006         0.05015
# 156     21.0     8.0             157            2.905         0.08658
# 157    141.0     8.0             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
#Description of dataset
#statistical summary of numerical columns.
df.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.047885                  0.846137    0.991046
# std          0.017146                  0.403121    0.272369
# min          0.018480                  0.000000    0.000000
# 25%          0.037268                  0.545808    0.856823
# ...

# %% [markdown]
# This gives the statistical summary of the numerical columns.The summary of the dataset looks perfect since there is no negative or invalid values present.

# %% [markdown]
# from the above description we can observe the following:

# %% [markdown]
# The counts of all the columns are same which means there are no missing values in the dataset

# %% [markdown]
# The mean value is less than the median in Happiness rank,Economy,Family,Health, Freedom columns

# %% [markdown]
# The mean value is greater than the median in Region ,Happiness score, Standard Error,Trust, Generosity, Dystopia Residual columns

# %% [markdown]
# The mean and median values are same in country column.

# %% [markdown]
# By summarizing the data we can observe there is a huge differences between 75% and max,hence there are outliers present in the data.

# %% [markdown]
# We can also notice that the standard deviation, minimum value and 25% percentile values from this describe method.

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.describe(), annot=True,fmt="0.2f",linewidth=0.2,linecolor="black",cmap="Accent")
plt.xlabel('figure',fontsize=10)
plt.ylabel("features_name",fontsize=15)
plt.title("Description of dataset",fontsize=20)
plt.show()

# %% [markdown]
# This gives the brief information about statistical summary of the dataset.

# %% [markdown]
# Data visualization:

# %%
sns.lmplot(x="Country",y="Happiness Score", data=df,palette="icefire")
plt.show()

# %% [markdown]
# Country is not having proper relation with Happiness score

# %%
sns.barplot(x="Country",y="Happiness Score", data=df,palette="icefire")
plt.show()

# %%
sns.lmplot(x="Region",y="Happiness Score", data=df,palette="icefire")
plt.show()

# %% [markdown]
# Region also not having strong relation with Happiness score

# %%
sns.lmplot(x="Happiness Rank",y="Happiness Score", data=df,palette="icefire")
plt.show()

# %% [markdown]
# Happiness Rank is negatively related with Happiness score,if Rank is 1,Then Happiness score will be higher than others.

# %%
sns.lmplot(x="Standard Error",y="Happiness Score", data=df,palette="icefire")
plt.show()

# %% [markdown]
# Standard Error also not having positive relation with Happiness score

# %%
sns.lmplot(x="Economy (GDP per Capita)",y="Happiness Score", data=df,palette="icefire")
plt.show()

# %% [markdown]
# Economy(GDP per Capita) has a positive relation with Happiness Score.

# %%
sns.lmplot(x="Family",y="Happiness Score", data=df,palette="icefire")
plt.show()

# %% [markdown]
# Family has a positive relation with Happiness Score.

# %%
sns.lmplot(x="Health (Life Expectancy)",y="Happiness Score", data=df,palette="icefire")
plt.show()

# %% [markdown]
# Health(Life Expectancy) has a positive relation with Happiness Score.

# %%
sns.lmplot(x="Freedom",y="Happiness Score", data=df,palette="icefire")
plt.show()

# %% [markdown]
# Freedom has not a high positive relation with Happiness Score.

# %%
sns.lmplot(x="Trust (Government Corruption)",y="Happiness Score", data=df,palette="icefire")
plt.show()

# %% [markdown]
# Trust has not a high positive relation with Happiness Score.

# %%
sns.lmplot(x="Generosity",y="Happiness Score", data=df,palette="icefire")
plt.show()

# %% [markdown]
# Generosity has not that much relation with Happiness Score.

# %%
sns.lmplot(x="Dystopia Residual",y="Happiness Score", data=df,palette="icefire")
plt.show()

# %% [markdown]
# Dystopia Residual has a positive relation with Happiness Score.

# %%
sns.pairplot(data=df,palette="Dark2")

# %% [markdown]
# This pair plot gives the pairwise relation between the features.On the diagonal we can notice the distribution plots.

# %%
df.dtypes
# Out:
# Country                          float64
# Region                           float64
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
#let's visualize how the data has been distributed in all  the columns.
plt.figure(figsize=(10,10),facecolor="blue")
plotnumber=1
for column in df.columns:
    if plotnumber<=12:
        ax=plt.subplot(3,4,plotnumber)
        sns.distplot(df[column],color="m")
        plt.xlabel(column,fontsize=10)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
    plt.tight_layout()

# %% [markdown]
# from the above , we can see the skewness in Trust,Standard error , generosity,family,health columns.

# %%
#let's visualize  the data to check the outliers by plotting boxplot  for all  the columns.
plt.figure(figsize=(10,10),facecolor="blue")
plotnumber=1
for column in df.columns:
    if plotnumber<=12:
        ax=plt.subplot(3,4,plotnumber)
        sns.boxplot(df[column],color="m")
        plt.xlabel(column,fontsize=10)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
    plt.tight_layout()

# %% [markdown]
# Standard Error, Family, Trust(Government Corruption),Generosity and Dystopia Residual columns has outliers.

# %% [markdown]
# so,remove the outliers using Z score

# %%
#now removing the data above zscore
from scipy.stats import zscore
a=df[['Standard Error','Trust (Government Corruption)','Generosity','Family']]
z_score=zscore(a)
abs_z_score=np.abs(z_score)
b=((abs_z_score<3).all(axis=1))
df1=df[b]
df1
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135.0     9.0               1            7.587         0.03411
# 1       58.0     9.0               2            7.561         0.04884
# 2       37.0     9.0               3            7.527         0.03328
# 3      105.0     9.0               4            7.522         0.03880
# 4       24.0     5.0               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 151     20.0     8.0             152            3.587         0.04324
# 152      0.0     7.0             153            3.575         0.03084
# 154     13.0     8.0             155            3.340         0.03656
# 155    136.0     4.0             156            3.006         0.05015
# 156     21.0     8.0             157            2.905         0.08658
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
#threshold=3
np.where(abs_z_score>3)
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 157], dtype=int64),
#  array([1, 0, 0, 0, 2, 3, 1, 3], dtype=int64))

# %%
print("Data loss percentage:",((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data loss percentage: 5.063291139240507

# %%
df1.dtypes
# Out:
# Country                          float64
# Region                           float64
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
#checking for skewness
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# Standard Error, Family,Health (Life Expectancy),Trust(Government Corruption) and Generosity columns have skewness.

# %%
#Removing skewness using sqrt root method.
df['Standard Error']=np.sqrt(df['Standard Error'])
df['Family']=np.sqrt(df['Family'])
df['Health (Life Expectancy)']=np.sqrt(df['Health (Life Expectancy)'])
df['Trust (Government Corruption)']=np.sqrt(df['Trust (Government Corruption)'])
df['Generosity']=np.sqrt(df['Generosity'])

# %%
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.225889
# Economy (GDP per Capita)        -0.317575
# Family                          -2.193070
# Health (Life Expectancy)        -1.380270
# Freedom                         -0.413462
# Trust (Government Corruption)    0.507663
# Generosity                      -0.130961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# still we can observe the skewness in Standard Error,Health,Family columns.

# %%
#Let us visualize again after removing skewness.
#let's visualize how the data has been distributed in all  the columns.
plt.figure(figsize=(10,10),facecolor="blue")
plotnumber=1
for column in df.columns:
    if plotnumber<=12:
        ax=plt.subplot(3,4,plotnumber)
        sns.distplot(df[column],color="m")
        plt.xlabel(column,fontsize=10)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
    plt.tight_layout()

# %% [markdown]
# The data almost looks normal but still some skewness is present in Standard Error, Family, Health columns.

# %%
#correlation between Dependent variables and independent variable
df.corr()
# Out:
#                                 Country    Region  Happiness Rank  \
# Country                        1.000000  0.005092       -0.098538
# Region                         0.005092  1.000000        0.213773
# Happiness Rank                -0.098538  0.213773        1.000000
# Happiness Score                0.083380 -0.176791       -0.992105
# Standard Error                 0.027663 -0.040740        0.177066
# Economy (GDP per Capita)       0.037808 -0.260139       -0.785267
# Family                         0.163460 -0.180243       -0.674380
# Health (Life Expectancy)       0.041403 -0.386945       -0.679526
# Freedom                        0.085684  0.092567       -0.556886
# Trust (Government Corruption)  0.065993  0.203203       -0.332354
# Generosity                     0.119919  0.285324       -0.151674
# Dystopia Residual             -0.019778 -0.057276       -0.521999
#
#                                Happiness Score  Standard Error  \
# ...

# %% [markdown]
# This gives the correlation between dependent and independent features.

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(), annot=True,fmt="0.2f",linewidth=0.2,linecolor="black",cmap="Accent")
plt.xlabel('figure',fontsize=10)
plt.ylabel("features_name",fontsize=15)
plt.title("correlation  of dependent and independent features",fontsize=20)
plt.show()

# %%
sort_values=df.corr()['Happiness Score'].sort_values(ascending=False)
sort_values
# Out:
# Happiness Score                  1.000000
# Economy (GDP per Capita)         0.780966
# Family                           0.683351
# Health (Life Expectancy)         0.664955
# Freedom                          0.568211
# Dystopia Residual                0.530474
# Trust (Government Corruption)    0.354664
# Generosity                       0.170428
# Country                          0.083380
# Region                          -0.176791
# Standard Error                  -0.196486
# Happiness Rank                  -0.992105
# Name: Happiness Score, dtype: float64

# %% [markdown]
# we can observe the positive correlated features and negative correlated features also.

# %%
#visualizing the correlation between features and target
plt.figure(figsize=(10,10))
df1.corr()['Happiness Score'].sort_values(ascending=False).drop(['Happiness Score']).plot(kind="bar",color="m")
plt.xlabel('feature',fontsize=15)
plt.ylabel('Target',fontsize=15)
plt.show()

# %% [markdown]
# The following columns: GDP per Capita, Family, Life Expectancy, Freedom, Generosity, Trust Government Corruption describe the extent to which these factors contribute in evaluating the happiness in each country

# %%
#seperating Features and label
X=df[['Dystopia Residual','Country','Region','Standard Error','Happiness Rank']]
Y=df["Happiness Score"]

# %%
X.shape
# Out:
# (158, 5)

# %%
Y.shape
# Out:
# (158,)

# %% [markdown]
# Feature scaling using standard scaler:

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(X),columns=X.columns)
x
# Out:
#      Dystopia Residual   Country    Region  Standard Error  Happiness Rank
# 0             0.758258  1.238770  1.300256       -0.875515       -1.721000
# 1             1.092857 -0.449465  1.300256        0.142929       -1.699075
# 2             0.712335 -0.909893  1.300256       -0.938931       -1.677149
# 3             0.663893  0.581016  1.300256       -0.530836       -1.655224
# 4             0.639337 -1.194920 -0.040302       -0.768784       -1.633299
# ..                 ...       ...       ...             ...             ...
# 153          -2.588925  0.866043  0.965117       -0.835423        1.633576
# 154          -0.843967 -1.436096  0.965117       -0.692695        1.655501
# 155          -3.208430  1.260695 -0.375441        0.225513        1.677427
# 156          -0.481985 -1.260695  0.965117        2.197472        1.699352
# 157          -0.963612  1.370321  0.965117        1.219100        1.721277
#
# [158 rows x 5 columns]

# %% [markdown]
# we have scaled the data using Standard Scaler method to overcome the issue of biasness.

# %% [markdown]
# Checking Variance Inflation Factor:

# %%
#Finding variance inflation factor in each scaled column.
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
vif["features"]=x.columns
vif
# Out:
#    VIF values           features
# 0    1.450711  Dystopia Residual
# 1    1.022639            Country
# 2    1.063810             Region
# 3    1.086742     Standard Error
# 4    1.583404     Happiness Rank

# %% [markdown]
# By checking the vif values , we can observe that the multi collinearity problem is not present.All values are less than 5.

# %% [markdown]
# Modelling:

# %%
#import necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
#finding the random state
maxAccuracy=0
maxRs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,Y,test_size=0.30,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=metrics.r2_score(y_test,pred)
    if acc>maxAccuracy:
        maxAccuracy=acc
        maxRs=i
print("maximum r2_score is ",maxAccuracy,"on Random state",maxRs)
# Out:
# maximum r2_score is  0.9911344858793798 on Random state 12

# %%
#creating train test split
x_train,x_test,y_train,y_test=train_test_split(x,Y,test_size=0.30,random_state=200)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
#Model initiation for LinearRegression
name=LinearRegression()
name.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn import metrics

# %%
def r2_score(name,x_train,x_test,y_train,y_test,train=True):
    if train:
        y_pred=name.predict(x_train)
        print("r2_score on training data",metrics.r2_score(y_train,y_pred)*100)
        
    else:
         if train==False:
            y_test_pred=name.predict(x_test)
            print("r2_score:",metrics.r2_score(y_test,y_test_pred))
            print("Mean absolute error:-",mean_absolute_error(y_test,y_test_pred))
            print("mean squared error:-",mean_squared_error(y_test,y_test_pred))
            print("Root mean squared error:-",np.sqrt(mean_squared_error(y_test,y_test_pred)))

# %%
r2_score(name,x_train,x_test,y_train,y_test,train=True)
r2_score(name,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data 98.55389059011685
# r2_score: 0.9872139943943788
# Mean absolute error:- 0.11135292129158846
# mean squared error:- 0.01717200793235901
# Root mean squared error:- 0.13104200827352658

# %%
y_test_pred=name.predict(x_test)
y_test_pred
# Out:
# array([3.67906495, 6.45349009, 3.82309959, 4.53529723, 4.21450005,
#        7.089736  , 6.18514171, 4.0077412 , 4.11888952, 6.47908287,
#        4.84838258, 4.58625558, 4.42893597, 4.30694715, 5.06480833,
#        3.81907454, 7.01013674, 5.16400845, 7.0276755 , 5.27364238,
#        5.39619453, 4.5304273 , 4.27393466, 7.4051429 , 6.16156089,
#        6.70280547, 3.79807561, 5.96163138, 5.83869404, 6.99023702,
#        3.92777359, 4.02271699, 6.82389857, 6.73586882, 6.23995293,
#        7.07160245, 3.89319806, 3.73131204, 5.02065298, 6.49309315,
#        5.50567923, 5.7410538 , 6.30844423, 4.62348653, 5.68347668,
#        7.29387899, 5.08592121, 3.61437455])

# %%
y_pred=name.predict(x_train)
y_pred
# Out:
# array([6.1257784 , 4.86219139, 7.12983607, 7.08379061, 5.7717326 ,
#        4.3886753 , 4.79396722, 4.57013627, 4.14144679, 5.56425059,
#        5.48702645, 3.68252738, 7.16389594, 6.77474658, 6.15410936,
#        4.74259502, 5.41628485, 6.84688271, 5.4723431 , 5.70685569,
#        6.54447963, 4.26537456, 4.49916562, 4.75047885, 3.43281681,
#        7.00801964, 5.21167905, 4.93787069, 6.1197598 , 6.16159768,
#        4.68307673, 6.3481802 , 6.36265455, 6.1698883 , 4.4697205 ,
#        5.46211236, 5.28757374, 5.71712336, 3.36020833, 6.17803781,
#        7.33420146, 3.7238461 , 5.87244998, 6.56975783, 4.39658157,
#        3.91628872, 6.71429171, 5.05086828, 6.64053506, 4.81735746,
#        4.94483583, 6.09039121, 4.64760467, 3.71234125, 5.58876612,
#        4.46366713, 6.57276626, 4.92594882, 5.22196453, 7.28197693,
#        4.32066392, 5.71092204, 3.56224856, 5.86848831, 3.62729711,
#        4.79881511, 5.45755637, 5.56522724, 4.09833307, 5.07281541,
# ...

# %%
from sklearn import metrics
print("r2_score on training data",metrics.r2_score(y_train,y_pred)*100)
# Out:
# r2_score on training data 98.55389059011685

# %%
print("r2_score:",metrics.r2_score(y_test,y_test_pred))
print("Mean absolute error:-",mean_absolute_error(y_test,pred))
print("mean squared error:-",mean_squared_error(y_test,pred))
print("Root mean squared error:-",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# r2_score: 0.9872139943943788
# Mean absolute error:- 1.301710051410142
# mean squared error:- 2.5962332080582597
# Root mean squared error:- 1.6112830937045979

# %% [markdown]
# The r2_score using linear regression is 98.72%

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score=cross_val_score(name,x,Y)
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score.mean())*100)
# Out:
# [-3.45019208 -0.65583376 -0.42317692 -0.5395124  -2.09154909]
# -1.4320528486939286
# Difference between R2 score and cross validation score is : 241.92668430883074

# %%
#Model initiation for RandomForestRegressor
name1= RandomForestRegressor()
name1.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
r2_score(name1,x_train,x_test,y_train,y_test,train=True)
r2_score(name1,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data 99.95293304791029
# r2_score: 0.9994523803327559
# Mean absolute error:- 0.02078645833333384
# mean squared error:- 0.0007354704479167179
# Root mean squared error:- 0.027119558401948914

# %% [markdown]
# The r2 score using RandomForestRegressor is 99.94%

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score1=cross_val_score(name1,x,Y)
print(score1)
print(score1.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score1.mean())*100)
# Out:
# [-3.4754315  -0.65797284 -0.45003038 -0.84518164 -2.10584306]
# -1.5068918866482415
# Difference between R2 score and cross validation score is : 249.41058810426205

# %%
#Model initiation for KNN
name2=KNN()
name2.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
r2_score(name2,x_train,x_test,y_train,y_test,train=True)
r2_score(name2,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data 91.58215887326348
# r2_score: 0.8653822778993783
# Mean absolute error:- 0.3498791666666667
# mean squared error:- 0.18079583749999995
# Root mean squared error:- 0.4252009377929451

# %% [markdown]
# The r2_score using KNN is 86.53%

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score2=cross_val_score(name2,x,Y)
print(score2)
print(score2.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score2.mean())*100)
# Out:
# [-10.64722669  -3.07847426  -3.24489615  -6.1147822   -5.17437567]
# -5.65195099357254
# Difference between R2 score and cross validation score is : 663.9164987966919

# %%
#Model initiation for GradientBoostingRegressor
name3=GradientBoostingRegressor()
name3.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
r2_score(name3,x_train,x_test,y_train,y_test,train=True)
r2_score(name3,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data 99.99970778170582
# r2_score: 0.9988434568737735
# Mean absolute error:- 0.028735882014358772
# mean squared error:- 0.0015532738175045187
# Root mean squared error:- 0.039411594962707595

# %% [markdown]
# The r2 score using  GradientBoostingRegressor is 99.88%

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score3=cross_val_score(name3,x,Y)
print(score3)
print(score3.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score3.mean())*100)
# Out:
# [-2.94939259 -0.29276184 -0.29364918 -0.36679501 -1.87462655]
# -1.1554450356578656
# Difference between R2 score and cross validation score is : 214.26590300522443

# %%
#Model initiation for lasso
name4=Lasso()
name4.fit(x_train,y_train)
# Out:
# Lasso()

# %%
r2_score(name4,x_train,x_test,y_train,y_test,train=True)
r2_score(name4,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data 17.66014735426713
# r2_score: 0.18286560075535463
# Mean absolute error:- 0.9157880021886049
# mean squared error:- 1.097437215220957
# Root mean squared error:- 1.0475863760191602

# %% [markdown]
# The r2 score using Lasso is very less and model is not performing well.

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score4=cross_val_score(name4,x,Y)
print(score4)
print(score4.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score4.mean())*100)
# Out:
# [-39.5383371   -6.65416738   0.19125992 -17.96627696 -23.65659767]
# -17.524823840209333
# Difference between R2 score and cross validation score is : 1851.203783460371

# %%
#Model initiation for Ridge
name5=Ridge()
name5.fit(x_train,y_train)
# Out:
# Ridge()

# %%
r2_score(name5,x_train,x_test,y_train,y_test,train=True)
r2_score(name5,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data 98.54032945283133
# r2_score: 0.98792518329564
# Mean absolute error:- 0.10711568734728251
# mean squared error:- 0.016216858855269977
# Root mean squared error:- 0.12734543123045278

# %% [markdown]
# The r2_score using Ridge is 98.79%

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score5=cross_val_score(name5,x,Y)
print(score5)
print(score5.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score5.mean())*100)
# Out:
# [0.15532069 0.45543329 0.72650445 0.25444809 0.73039794]
# 0.4644208897223594
# Difference between R2 score and cross validation score is : 52.279310467201945

# %%
#Model initiation for DecisionTreeRegressor
name6=DecisionTreeRegressor()
name6.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
r2_score(name6,x_train,x_test,y_train,y_test,train=True)
r2_score(name6,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data 100.0
# r2_score: 0.9970769175943651
# Mean absolute error:- 0.03970833333333328
# mean squared error:- 0.00392579166666667
# Root mean squared error:- 0.0626561382999836

# %% [markdown]
# The r2_score using DecisionTreeRegressor is 99.70%

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score6=cross_val_score(name6,x,Y)
print(score6)
print(score6.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score6.mean())*100)
# Out:
# [-3.04737285 -0.62841217 -0.30142988 -0.40639338 -1.88448492]
# -1.2536186396555538
# Difference between R2 score and cross validation score is : 224.08326340499326

# %%
from sklearn.ensemble import ExtraTreesRegressor
#Model initiation for ExtraTreesRegressor
name7=ExtraTreesRegressor()
name7.fit(x_train,y_train)
# Out:
# ExtraTreesRegressor()

# %%
r2_score(name7,x_train,x_test,y_train,y_test,train=True)
r2_score(name7,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data 100.0
# r2_score: 0.9991098847972103
# Mean absolute error:- 0.024981458333333456
# mean squared error:- 0.0011954527312500129
# Root mean squared error:- 0.03457531968398865

# %% [markdown]
# The r2 score using ExtraTrees Regressor is 99.91%

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score7=cross_val_score(name7,x,Y)
print(score7)
print(score7.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score7.mean())*100)
# Out:
# [-3.36155489  0.63663632  0.8752363   0.95760425 -1.99721523]
# -0.5778586495796334
# Difference between R2 score and cross validation score is : 156.5072643974012

# %%
from sklearn.svm import SVR
#Model initiation for SVR
name8=SVR()
name8.fit(x_train,y_train)
# Out:
# SVR()

# %%
r2_score(name8,x_train,x_test,y_train,y_test,train=True)
r2_score(name8,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data 96.96518319275141
# r2_score: 0.9566209962496391
# Mean absolute error:- 0.17706342998383617
# mean squared error:- 0.058259367270380474
# Root mean squared error:- 0.24136977290120748

# %% [markdown]
# The r2 score using SVR is 95.66%

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score8=cross_val_score(name8,x,Y)
print(score8)
print(score8.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score8.mean())*100)
# Out:
# [-10.21883099   0.10027457   0.54434322  -0.51496715  -6.52084046]
# -3.322004160865373
# Difference between R2 score and cross validation score is : 430.9218155259752

# %% [markdown]
# from the difference of both r2_score and cross validation score computed on r2 score we can conclude that Ridge Regression as our best fitting model and best performing model.

# %% [markdown]
# Hyper Parameter Tuning:

# %%
from sklearn.model_selection import GridSearchCV

# %%
param={'alpha':[1.0,.05,.4,2],
      'solver':['auto','cholesky','sag','saga'],
      'positive':[False,True],
      'random_state':[1,4,10]}

# %%
gsv=GridSearchCV(Ridge(),param,cv=5)
gsv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1.0, 0.05, 0.4, 2],
#                          'positive': [False, True], 'random_state': [1, 4, 10],
#                          'solver': ['auto', 'cholesky', 'sag', 'saga']})

# %%
gsv.best_params_
# Out:
# {'alpha': 0.05, 'positive': False, 'random_state': 4, 'solver': 'saga'}

# %%
Model=Ridge(alpha=0.05,positive=False,random_state=4,solver='saga')

# %%
Model.fit(x_train,y_train)
pred=Model.predict(x_test)

# %%
print("R2_score:",metrics.r2_score(y_test,pred))
print("Mean Absolute error:",mean_absolute_error(y_test,pred))
print("mean squared error:",mean_squared_error(y_test,pred))
print("Root mean squared error:",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.9872578165026815
# Mean Absolute error: 0.11114094183483103
# mean squared error: 0.017113153461729414
# Root mean squared error: 0.13081725215631695

# %%
#to save the model
import pickle
file_name="World_Happiness_project.pkl"
pickle.dump(Model,open(file_name,'wb'))

# %%
import pickle
loaded_model=pickle.load(open('World_Happiness_project.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 98.72578165026815

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=["predicted","original"])
conclusion
# Out:
#                 0         1        2         3         4         5         6   \
# predicted  3.68008  6.453268  3.82406  4.535969  4.214911  7.089063  6.184623
# original   3.65600  6.411000  3.90400  4.642000  4.369000  7.226000  5.948000
#
#                 7         8         9   ...        38        39        40  \
# predicted  4.00815  4.120232  6.478246  ...  5.021566  6.492946  5.505817
# original   4.03300  4.292000  6.302000  ...  4.971000  6.485000  5.548000
#
#                  41        42        43        44        45        46  \
# predicted  5.740469  6.308182  4.624136  5.683019  7.292621  5.086255
# original   5.689000  6.130000  4.715000  5.605000  7.427000  5.123000
#
#                  47
# predicted  3.614841
# original   3.587000
#
# [2 rows x 48 columns]
