# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Project Description:

# %% [markdown]
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.

# %% [markdown]
# 1.	W - This indicates the number of Wins credited to a pitcher: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work.

# %% [markdown]
# 2.	R - This indicates Runs scored. A run is scored when a player advances around first, second and third base and returns safely to home plate, touching the bases in that order, before three outs are recorded and all obligations to reach base safely on batted balls are met or assured: number of times a player crosses home plate.

# %% [markdown]
# 3.	AB - This means At bat or time at bat. It's is a batter's turn batting against a pitcher: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction

# %% [markdown]
# 4.	H - This means Hit. It's also called a "base hit", is credited to a batter when the batter safely reaches or passes first base after hitting the ball into fair territory, without the benefit of either an error or a fielder's choice: reaching base because of a batted, fair ball without error by the defense.

# %% [markdown]
# 5.	2B - This means the act of a batter striking the pitched ball and safely reaching second base without being called out by the umpire, without the benefit of a fielder's misplay (see error) or another runner being put out on a fielder's choice. A double is a type of hit (the others being the single, triple and home run) and is sometimes called a "two-bagger" or "two-base hit": hits on which the batter reaches second base safely without the contribution of a fielding error.

# %% [markdown]
# 6.	3B - This measns a Triple.It's is the act of a batter safely reaching third base after hitting the ball, with neither the benefit of a fielder's misplay nor another runner being put out on a fielder's choice. A triple is sometimes called a "three-bagger" or "three-base hit": hits on which the batter reaches third base safely without the contribution of a fielding error.

# %% [markdown]
# 7.	HR - This means Home runs. It's scored when the ball is hit in such a way that the batter is able to circle the bases and reach home plate safely in one play without any errors being committed by the defensive team. A home run is usually achieved by hitting the ball over the outfield fence between the foul poles (or hitting either foul pole) without the ball touching the field: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.

# %% [markdown]
# 8.	BB - This means Base on balls (also called a "walk"). It occurs in baseball when a batter receives four pitches that the umpire calls balls, and is in turn awarded first base without the possibility of being called out: hitter not swinging at four pitches called out of the strike zone and awarded first base.

# %% [markdown]
# 9.	SO - Also denoted as "K" means Strikeout. It occurs when a batter accumulates three strikes during a time at bat. It usually means that the batter is out: number of batters who received strike three.

# %% [markdown]
# 10.	SB - This means Stolen base. It occurs when a runner advances to a base to which they are not entitled and the official scorer rules that the advance should be credited to the action of the runner: number of bases advanced by the runner while the ball is in the possession of the defense.

# %% [markdown]
# 11.	RA - This means Run Average. It refer to measures of the rate at which runs are allowed or scored.

# %% [markdown]
# 12.	ER - This means Earned run. It refers to any run that was fully enabled by the offensive team's production in the face of competent play from the defensive team: number of runs that did not occur as a result of errors or passed balls.

# %% [markdown]
# 13.	ERA - This means Earned Run Average. It refers to the average of earned runs allowed by a pitcher per nine innings pitched (i.e. the traditional length of a game). It is determined by dividing the number of earned runs allowed by the number of innings pitched and multiplying by nine: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched

# %% [markdown]
# 14.	CG - This means Complete Game. It's the act of a pitcher pitching an entire game without the benefit of a relief pitcher. A pitcher who meets this criterion will be credited with a complete game regardless of the number of innings played: number of games where player was the only pitcher for their team.

# %% [markdown]
# 15.	SHO - This means Shutout. It refers to the act by which a single pitcher pitches a complete game and does not allow the opposing team to score a run: number of complete games pitched with no runs allowed.

# %% [markdown]
# 16.	SV - This means Save. It's credited to a pitcher who finishes a game for the winning team under certain prescribed circumstances: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.

# %% [markdown]
# 17.	E - This means Errors. It's an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out. The term error is sometimes used to refer to the play during which an error was committed: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# Exploratory Data Analysis:

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# There are 30 rows and 17 columns present in the dataset.

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# These are the columns present in the dataset.

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# There are two types of data int64 and float64 present in the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# This gives the information about the columns, non-null count ,dtype and memory usage of the dataset.

# %%
#Checking the null values
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# There are no null values present in the dataset.

# %%
#Checking the duplicated values
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicate values present in the dataset.

# %%
#Let's check null values using heatmap
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# we can clearly see that there are no null values present in the dataset.

# %%
for i in df.columns:
    print(df[i].value_counts())
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: R, dtype: int64
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# Name: AB, dtype: int64
# ...

# %%
df["E"].value_counts()
# Out:
# 88     3
# 90     3
# 86     3
# 93     2
# 77     2
# 95     2
# 122    1
# 78     1
# 75     1
# 117    1
# 116    1
# 111    1
# 94     1
# 96     1
# 126    1
# 85     1
# 119    1
# 97     1
# 101    1
# 79     1
# 92     1
# Name: E, dtype: int64

# %%
#checking number of unique values in each column
df.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %% [markdown]
# These are the unique values present in the dataset.

# %% [markdown]
# Description of Dataset:

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# This gives the statistical summary of the dataset.The summary of the dataset looks perfect since there is no invalid/negative values present.

# %% [markdown]
# The counts of all the columns are same which means there are no missing values in the dataset.

# %% [markdown]
# The mean is less than the median in W,R,2B,BB,SO,RA,ER,ERA,SHO columns which means the data is skewed to left in these columns.

# %% [markdown]
# The mean is greater than the median in AB,H,3B,HR,CG,SV,E columns which means the data is skewed to right in these columns.

# %% [markdown]
# The mean and median are same in SB column which means the data looks normal and not skewed.

# %% [markdown]
# By summarizing the data, we can observe there is a huge difference between 75% and max,hence there are outliers present in the data.
#
# we can also observe the standard deviation values and min(25%) values from this describe method.

# %%
#let us visualize using heatmap
plt.figure(figsize=(20,10))
sns.heatmap(df.describe(),annot=True,fmt='0.2f',linewidth=0.9,linecolor='red',cmap='Spectral')
plt.title("Description of Dataset",fontsize=10)
plt.xlabel("Figure",fontsize=15)
plt.ylabel("Features_Name",fontsize=15)
plt.show()

# %% [markdown]
# Data Visualization:

# %% [markdown]
# Univariate Analysis:

# %%
#Let's visualize W column
sns.countplot(x="W",data=df)
plt.show()

# %% [markdown]
# The value 68 occurance is more in this W column and occurance of 74,76,83 and 84 are same and remaining all values occurance is same.

# %%
#Let's visualize R column
sns.countplot(x="R",data=df)
print(df["R"].value_counts())
plt.show()
# Out:
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: R, dtype: int64

# %% [markdown]
# All values are unique except 689 and 696 values.

# %%
#Let's visualize AB column
sns.countplot(x="AB",data=df)
print(df["AB"].value_counts())
plt.show()
# Out:
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# Name: AB, dtype: int64

# %% [markdown]
# All values are unique except 5485 and 5485 value occured 2 times

# %%
#Let's visualize H column
sns.countplot(x="H",data=df)
print(df["H"].value_counts())
plt.show()
# Out:
# 1363    2
# 1497    1
# 1386    1
# 1324    1
# 1494    1
# 1486    1
# 1346    1
# 1374    1
# 1361    1
# 1420    1
# 1351    1
# 1382    1
# 1378    1
# 1341    1
# 1462    1
# 1405    1
# 1349    1
# 1379    1
# 1331    1
# 1419    1
# 1495    1
# 1383    1
# 1370    1
# 1397    1
# 1480    1
# 1515    1
# 1381    1
# 1395    1
# 1479    1
# Name: H, dtype: int64

# %% [markdown]
# All values are unique except 1363 and 1363 value occurs two times

# %%
#Let's visualize 2B column
sns.countplot(x="2B",data=df)
print(df["2B"].value_counts())
plt.show()
# Out:
# 272    3
# 260    2
# 289    2
# 278    2
# 277    2
# 274    2
# 288    2
# 300    1
# 292    1
# 251    1
# 236    1
# 265    1
# 295    1
# 257    1
# 243    1
# 262    1
# 279    1
# 294    1
# 246    1
# 308    1
# 303    1
# 263    1
# Name: 2B, dtype: int64

# %% [markdown]
# The value 272 occurance is more compared to others.

# %%
#Let's visualize 3B column
sns.countplot(x="3B",data=df)
print(df["3B"].value_counts())
plt.show()
# Out:
# 27    3
# 39    2
# 49    2
# 17    2
# 32    2
# 26    2
# 42    1
# 48    1
# 37    1
# 18    1
# 40    1
# 13    1
# 34    1
# 30    1
# 21    1
# 46    1
# 22    1
# 44    1
# 33    1
# 20    1
# 19    1
# 29    1
# 36    1
# Name: 3B, dtype: int64

# %% [markdown]
# The value 27 occured more times

# %%
#Let's visualize HR column
sns.countplot(x="HR",data=df)
print(df["HR"].value_counts())
plt.show()
# Out:
# 136    2
# 167    2
# 177    2
# 139    1
# 137    1
# 148    1
# 154    1
# 187    1
# 130    1
# 100    1
# 120    1
# 145    1
# 171    1
# 140    1
# 198    1
# 146    1
# 156    1
# 176    1
# 230    1
# 172    1
# 161    1
# 217    1
# 212    1
# 232    1
# 151    1
# 141    1
# 186    1
# Name: HR, dtype: int64

# %% [markdown]
# All values are unique except 136,167,177 values

# %%
#Let's visualize BB column
sns.countplot(x="BB",data=df)
print(df["BB"].value_counts())
plt.show()
# Out:
# 478    2
# 383    1
# 461    1
# 426    1
# 490    1
# 457    1
# 563    1
# 387    1
# 471    1
# 375    1
# 539    1
# 488    1
# 496    1
# 412    1
# 567    1
# 506    1
# 439    1
# 475    1
# 435    1
# 486    1
# 503    1
# 436    1
# 418    1
# 554    1
# 570    1
# 455    1
# 404    1
# 533    1
# 388    1
# Name: BB, dtype: int64

# %% [markdown]
# All values are unique except 478 and this value occurs two times in this column.

# %%
#Let's visualize SO column
sns.countplot(x="SO",data=df)
print(df["SO"].value_counts())
plt.show()
# Out:
# 1150    2
# 973     1
# 1267    1
# 1327    1
# 1312    1
# 1159    1
# 1258    1
# 1274    1
# 1107    1
# 1344    1
# 1290    1
# 1255    1
# 1299    1
# 1518    1
# 1322    1
# 1119    1
# 1264    1
# 1336    1
# 1392    1
# 1233    1
# 1148    1
# 1310    1
# 1331    1
# 1227    1
# 1151    1
# 1259    1
# 1231    1
# 1157    1
# 1283    1
# Name: SO, dtype: int64

# %% [markdown]
# The value 1150 occured two times and remaining values are unique.

# %%
#Let's visualize SB column
sns.countplot(x="SB",data=df)
print(df["SB"].value_counts())
plt.show()
# Out:
# 69     3
# 88     2
# 78     1
# 82     1
# 132    1
# 93     1
# 59     1
# 112    1
# 57     1
# 51     1
# 134    1
# 84     1
# 95     1
# 98     1
# 104    1
# 70     1
# 52     1
# 121    1
# 101    1
# 71     1
# 87     1
# 44     1
# 63     1
# 83     1
# 68     1
# 86     1
# 97     1
# Name: SB, dtype: int64

# %% [markdown]
# The value 69 occurance is more compared to other values.

# %%
#Let's visualize RA column
sns.countplot(x="RA",data=df)
print(df["RA"].value_counts())
plt.show()
# Out:
# 641    1
# 700    1
# 731    1
# 713    1
# 627    1
# 595    1
# 809    1
# 760    1
# 678    1
# 635    1
# 613    1
# 754    1
# 737    1
# 608    1
# 596    1
# 525    1
# 729    1
# 726    1
# 675    1
# 618    1
# 733    1
# 753    1
# 642    1
# 693    1
# 698    1
# 670    1
# 803    1
# 701    1
# 640    1
# 844    1
# Name: RA, dtype: int64

# %% [markdown]
# All values are unique in this column.

# %%
#Let's visualize ERA column
sns.countplot(x="ERA",data=df)
print(df["ERA"].value_counts())
plt.show()
# Out:
# 3.73    1
# 4.07    1
# 4.09    1
# 4.04    1
# 3.72    1
# 3.44    1
# 4.69    1
# 4.41    1
# 4.02    1
# 3.62    1
# 3.43    1
# 4.33    1
# 4.28    1
# 3.36    1
# 3.21    1
# 2.94    1
# 4.14    1
# 4.16    1
# 3.94    1
# 3.57    1
# 4.24    1
# 4.31    1
# 3.74    1
# 4.05    1
# 4.03    1
# 3.80    1
# 4.64    1
# 3.98    1
# 3.67    1
# 5.04    1
# Name: ERA, dtype: int64

# %% [markdown]
# All values are unique in this ERA column.

# %%
#Let's visualize ER column
sns.countplot(x="ER",data=df)
print(df["ER"].value_counts())
plt.show()
# Out:
# 601    1
# 653    1
# 655    1
# 659    1
# 597    1
# 553    1
# 749    1
# 698    1
# 638    1
# 577    1
# 557    1
# 700    1
# 682    1
# 546    1
# 532    1
# 478    1
# 664    1
# 677    1
# 630    1
# 572    1
# 680    1
# 694    1
# 604    1
# 646    1
# 652    1
# 609    1
# 746    1
# 643    1
# 584    1
# 799    1
# Name: ER, dtype: int64

# %% [markdown]
# All values are uniquely occured here.

# %%
#Let's visualize CG column
sns.countplot(x="CG",data=df)
print(df["CG"].value_counts())
plt.show()
# Out:
# 1     7
# 2     4
# 7     4
# 3     3
# 0     3
# 5     3
# 6     3
# 4     2
# 11    1
# Name: CG, dtype: int64

# %% [markdown]
# The value 1 occured more times compared to others.

# %%
#Let's visualize SHO column
sns.countplot(x="SHO",data=df)
print(df["SHO"].value_counts())
plt.show()
# Out:
# 12    7
# 10    5
# 13    3
# 8     2
# 9     2
# 4     2
# 15    2
# 21    2
# 7     2
# 14    1
# 18    1
# 6     1
# Name: SHO, dtype: int64

# %% [markdown]
# The value 12 occurance is more.

# %%
#Let's visualize SV column
sns.countplot(x="SV",data=df)
print(df["SV"].value_counts())
plt.show()
# Out:
# 35    4
# 41    3
# 45    3
# 44    2
# 48    2
# 40    2
# 56    1
# 28    1
# 47    1
# 50    1
# 54    1
# 62    1
# 39    1
# 46    1
# 60    1
# 43    1
# 34    1
# 37    1
# 38    1
# 36    1
# Name: SV, dtype: int64

# %% [markdown]
# The value 35 occurance is more.

# %%
#Let's visualize E column
sns.countplot(x="E",data=df)
print(df["E"].value_counts())
plt.show()
# Out:
# 88     3
# 90     3
# 86     3
# 93     2
# 77     2
# 95     2
# 122    1
# 78     1
# 75     1
# 117    1
# 116    1
# 111    1
# 94     1
# 96     1
# 126    1
# 85     1
# 119    1
# 97     1
# 101    1
# 79     1
# 92     1
# Name: E, dtype: int64

# %% [markdown]
# The occurance of 86,88,90 values are same and 77,93 and 95 values occurances are same.

# %% [markdown]
# Bivariate Analysis:

# %%
#compare W  and E column
sns.lmplot(x="W",y="E",data=df,palette="icefire")
plt.show()

# %% [markdown]
# W has a negative relation with E

# %%
#compare R and E column
sns.lmplot(x="R",y="E",data=df,palette="icefire")
plt.show()

# %% [markdown]
# R has not a high relation with E

# %%
#compare AB and E column
sns.lmplot(x="AB",y="E",data=df,palette="icefire")
plt.show()

# %% [markdown]
# AB has a positive relation with E

# %%
#compare H and E column
sns.lmplot(x="H",y="E",data=df,palette="icefire")
plt.show()

# %% [markdown]
# H has not have a high relation with E.

# %%
#compare 2B and E column
sns.lmplot(x="2B",y="E",data=df,palette="icefire")
plt.show()

# %% [markdown]
# 2B has a positive relation with E

# %%
#compare 3B and E column
sns.lmplot(x="3B",y="E",data=df,palette="icefire")
plt.show()

# %% [markdown]
# 3B has a positive relation with E

# %%
#compare HR and E column
sns.lmplot(x="HR",y="E",data=df,palette="icefire")
plt.show()

# %% [markdown]
# HR has a negative relation with E

# %%
#compare BB and E column
sns.lmplot(x="BB",y="E",data=df,palette="icefire")
plt.show()

# %% [markdown]
# BB has a negative relation with E

# %%
#compare SO and E column
sns.lmplot(x="SO",y="E",data=df,palette="icefire")
plt.show()

# %% [markdown]
# SO has a positive relation with E

# %%
#compare SB and E column
sns.lmplot(x="SB",y="E",data=df,palette="icefire")
plt.show()

# %% [markdown]
# SB has a positive relation with E

# %%
#compare RA and E column
sns.lmplot(x="RA",y="E",data=df,palette="icefire")
plt.show()

# %% [markdown]
# RA has a positive relation with E

# %%
#compare ER and E column
sns.lmplot(x="ER",y="E",data=df,palette="icefire")
plt.show()

# %% [markdown]
# ER has a positive relation with E

# %%
#compare ERA and E column
sns.lmplot(x="ERA",y="E",data=df,palette="icefire")
plt.show()

# %% [markdown]
# ERA has a positive relation with E

# %%
#compare CG and E column
sns.lmplot(x="CG",y="E",data=df,palette="icefire")
plt.show()

# %% [markdown]
# CG has a negative relation with E

# %%
#compare SHO and E column
sns.lmplot(x="SHO",y="E",data=df,palette="icefire")
plt.show()

# %% [markdown]
# SHO has a negative relation with E

# %%
#compare sv and E column
sns.lmplot(x="SV",y="E",data=df,palette="icefire")
plt.show()

# %% [markdown]
# SV has not have a high relation with E

# %%
sns.pairplot(data=df,palette='Dark2')

# %% [markdown]
#  This pairplot gives the pairwise relation between the features.On the diagonal we can see the distribution plots.Remaining columns ERA and ER have strong linear relation with  the RA column..

# %%
#let's visualize how the data has been distributed in all  the columns.
plt.figure(figsize=(10,10),facecolor="blue")
plotnumber=1
for column in df:
    if plotnumber<=17:
        ax=plt.subplot(6,3,plotnumber)
        sns.distplot(df[column],color="m")
        plt.xlabel(column,fontsize=10)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
    plt.tight_layout()

# %% [markdown]
# The data is right skewed in R and H columns

# %%
#let's visualize the data to check the outliers in all  the columns.
plt.figure(figsize=(10,10),facecolor="blue")
plotnumber=1
for column in df:
    if plotnumber<=17:
        ax=plt.subplot(6,3,plotnumber)
        sns.boxplot(df[column],color="m")
        plt.xlabel(column,fontsize=10)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
    plt.tight_layout()

# %% [markdown]
# The columns R,ERA,SV,SHO and E have outliers.

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
#            W         R        AB         H        2B        3B        HR  \
# 0   1.365409  0.619078  0.847731  1.663685  1.420173  1.041193  0.787299
# 1   0.197838  0.134432  0.711094  0.970681  0.127403  1.235809  0.243967
# 2   0.003243  0.332906  1.115233  0.151891  1.588795  0.223808  0.723377
# 3   0.483244  1.146419  0.241522  0.401088  0.828122  0.418423  0.883181
# 4   0.677839  0.013270  1.280738  1.984081  0.801892  1.722347  0.403770
# 5   1.170814  3.509647  0.104884  1.361089  1.869832  1.391501  2.185047
# 6   0.587028  1.311430  0.732263  0.116292  0.153633  1.196885  1.545833
# 7   0.003243  0.428681  0.451289  0.596886  1.615025  1.099578  1.705636
# 8   0.094054  0.765626  0.451289  0.365489  0.183611  0.068115  0.107601
# 9   0.288649  1.034489  1.785913  1.628086  1.082929  0.165423  0.084163
# 10  0.684326  1.086415  0.076017  0.275303  0.239818  0.068115  0.267405
# 11  0.489731  0.705622  0.826562  0.721484  0.183611  0.515731  2.121125
# ...

# %%
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
#the data where the outliers are present,in this only at one point outlier present.
z.iloc[5,1]
# Out:
# 3.5096470447193067

# %%
#now removing the data above z score
z=zscore(df)
abs_z_score=np.abs(z)
b=((abs_z_score<3).all(axis=1))
df1=df[b]
df1
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %%
print("Data loss percentage:",((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data loss percentage: 3.3333333333333335

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %% [markdown]
# This gives the correlation between dependent and independent variables.Let's visualize it using heatmap.

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True,fmt="0.2f",linecolor="black",linewidth=0.2)
# Out:
# <AxesSubplot:>

# %%
df.corr()["E"].sort_values(ascending=False)
# Out:
# E      1.000000
# AB     0.316743
# RA     0.198996
# SO     0.155133
# ER     0.136921
# 3B     0.126678
# ERA    0.113137
# 2B     0.105754
# SB     0.079149
# R     -0.023262
# SV    -0.025636
# H     -0.033173
# BB    -0.075685
# W     -0.089485
# SHO   -0.115716
# CG    -0.140047
# HR    -0.207597
# Name: E, dtype: float64

# %% [markdown]
# we can observe both the positive and negative correlated features with the target.

# %%
#visualizing the correlation between features and target
plt.figure(figsize=(10,10))
df.corr()['E'].sort_values(ascending=False).drop(['E']).plot(kind="bar",color="m")
plt.xlabel('feature',fontsize=15)
plt.ylabel('Target',fontsize=15)
plt.show()

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# R,H,CG,SV and E columns have skewness since E is the target column,no need to remove skewness.Let us remove skewness using squareroot method.

# %%
df["R"]=np.sqrt(df["R"])
df["H"]=np.sqrt(df["H"])
df["CG"]=np.sqrt(df["CG"])
df["SV"]=np.sqrt(df["SV"])

# %%
df.skew()
# Out:
# W      0.047089
# R      0.968676
# AB     0.183437
# H      0.649567
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG    -0.311476
# SHO    0.565790
# SV     0.410288
# E      0.890132
# dtype: float64

# %% [markdown]
# still some skewness is observed in R column.

# %% [markdown]
# Seperating Features and Label:

# %%
#separating the features and target variables in to x and y.
x=df.drop("E",axis=1)
y=df['E']

# %%
x
# Out:
#       W          R    AB          H   2B  3B   HR   BB    SO   SB   RA   ER  \
# 0    95  26.907248  5575  38.691084  300  42  139  383   973  104  641  601
# 1    83  26.381812  5467  36.728735  277  44  156  439  1264   70  700  653
# 2    81  25.865034  5439  37.349699  303  29  141  533  1157   86  640  584
# 3    76  24.939928  5533  37.161808  260  27  136  404  1231   68  701  643
# 4    74  26.248809  5605  38.923001  289  49  151  455  1259   83  803  746
# 5    93  29.849623  5509  38.470768  308  17  232  570  1151   88  670  609
# 6    87  27.640550  5567  37.376463  272  19  212  554  1227   63  698  652
# 7    81  26.702060  5485  37.013511  246  20  217  418  1331   44  693  646
# 8    80  25.377155  5485  37.188708  278  32  167  436  1310   87  642  604
# 9    78  27.349589  5640  38.665230  294  33  161  478  1148   71  753  694
# 10   88  27.404379  5511  37.669616  279  32  172  503  1233  101  733  680
# ...

# %%
y
# Out:
# 0      88
# 1      86
# 2      79
# 3     101
# 4      86
# 5      88
# 6      93
# 7      77
# 8      95
# 9      97
# 10    119
# 11     85
# 12     93
# 13     94
# 14    126
# 15     96
# 16    122
# 17    111
# 18    116
# 19     90
# 20     88
# 21     90
# 22     77
# 23     90
# 24    117
# 25     75
# 26     78
# 27     86
# 28     92
# 29     95
# Name: E, dtype: int64

# %%
y.value_counts()
# Out:
# 88     3
# 90     3
# 86     3
# 93     2
# 77     2
# 95     2
# 122    1
# 78     1
# 75     1
# 117    1
# 116    1
# 111    1
# 94     1
# 96     1
# 126    1
# 85     1
# 119    1
# 97     1
# 101    1
# 79     1
# 92     1
# Name: E, dtype: int64

# %% [markdown]
# Feature scaling using Robust scaler:

# %%
from sklearn.preprocessing import RobustScaler
scaler=RobustScaler()
x1=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x1
# Out:
#            W         R        AB         H        2B      3B        HR  \
# 0   1.018182  0.514180  0.613208  1.280012  0.924528  0.6875 -0.530612
# 1   0.145455  0.103863 -0.405660 -0.384444  0.056604  0.8125 -0.068027
# 2   0.000000 -0.299693 -0.669811  0.142255  1.037736 -0.1250 -0.476190
# 3  -0.363636 -1.022115  0.216981 -0.017113 -0.584906 -0.2500 -0.612245
# 4  -0.509091  0.000000  0.896226  1.476723  0.509434  1.1250 -0.204082
# 5   0.872727  2.811902 -0.009434  1.093141  1.226415 -0.8750  2.000000
# 6   0.436364  1.086820  0.537736  0.164956 -0.132075 -0.7500  1.455782
# 7   0.000000  0.353947 -0.235849 -0.142898 -1.113208 -0.6875  1.591837
# 8  -0.072727 -0.680681 -0.235849  0.005703  0.094340  0.0625  0.231293
# 9  -0.218182  0.859607  1.226415  1.258082  0.698113  0.1250  0.068027
# 10  0.509091  0.902393  0.009434  0.413607  0.132075  0.0625  0.367347
# 11  0.363636  0.586610 -0.481132 -0.223206  0.094340 -0.3125  1.945578
# ...

# %% [markdown]
# we have scaled the data using Robust Scaler method to overcome the issue of biasness.

# %%
#Finding variance inflation factor in each scaled column.
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x1.values,i) for i in range(x1.shape[1])]
vif["features"]=x1.columns
vif
# Out:
#      VIF values features
# 0     17.579501        W
# 1     18.798589        R
# 2      9.332687       AB
# 3      3.872287        H
# 4      4.497117       2B
# 5      2.809985       3B
# 6      8.601639       HR
# 7      4.103130       BB
# 8      2.607997       SO
# 9      1.858405       SB
# 10   158.434035       RA
# 11  1666.025713       ER
# 12  1146.461104      ERA
# 13     3.327740       CG
# 14     3.664241      SHO
# 15     8.116630       SV

# %% [markdown]
# By checking the vif values we can find the features causing multi collinearity problem.Here we can find the features RA,ER,ERA  columns have high vif value .so we will drop the column  having high vif

# %%
x1.drop("ER",inplace=True,axis=1)

# %%
# Again checking  variance inflation factor in each scaled column.
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x1.values,i) for i in range(x1.shape[1])]
vif["features"]=x1.columns
vif
# Out:
#     VIF values features
# 0    17.406407        W
# 1    16.203639        R
# 2     3.762871       AB
# 3     3.868055        H
# 4     4.338681       2B
# 5     2.769235       3B
# 6     5.612542       HR
# 7     4.099598       BB
# 8     2.496587       SO
# 9     1.714120       SB
# 10   82.104141       RA
# 11   84.376647      ERA
# 12    3.215734       CG
# 13    3.587520      SHO
# 14    6.681489       SV

# %% [markdown]
# se we have solved multi collinearity issue.we can now move ahead for model building.

# %% [markdown]
# Modelling:

# %%
#import necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
#creating train test split
x_train,x_test,y_train,y_test=train_test_split(x1,y,test_size=0.30,random_state=200)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
#Model initiation for LinearRegression
name=LinearRegression()
name.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn import metrics

# %%
def r2_score(name,x_train,x_test,y_train,y_test,train=True):
    if train:
        y_pred=name.predict(x_train)
        print("r2_score on training data",metrics.r2_score(y_train,y_pred)*100)
        
    else:
         if train==False:
            y_test_pred=name.predict(x_test)
            print("r2_score:",metrics.r2_score(y_test,y_test_pred))
            print("Mean absolute error:-",mean_absolute_error(y_test,y_test_pred))
            print("mean squared error:-",mean_squared_error(y_test,y_test_pred))
            print("Root mean squared error:-",np.sqrt(mean_squared_error(y_test,y_test_pred)))

# %%
r2_score(name,x_train,x_test,y_train,y_test,train=True)
r2_score(name,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data 68.60218866064687
# r2_score: -3.206186705307024
# Mean absolute error:- 23.476450593027383
# mean squared error:- 745.8971090744457
# Root mean squared error:- 27.311116950327126

# %% [markdown]
# r2 score using linear regression is -32.06%

# %%
#finding the random state
maxAccuracy=0
maxRs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x1,y,test_size=0.30,random_state=i)
    name=LinearRegression()
    name.fit(x_train,y_train)
    y_test_pred=name.predict(x_test)
    acc=metrics.r2_score(y_test,y_test_pred)
    if acc>maxAccuracy:
        maxAccuracy=acc
        maxRs=i
print("maximum r2_score is ",maxAccuracy,"on Random state",maxRs)
# Out:
# maximum r2_score is  0.16332196781810793 on Random state 172

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score=cross_val_score(name,x1,y)
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score.mean())*100)
# Out:
# [-4.64696843 -0.58398165 -3.72382433 -1.39519366 -4.14135452]
# -2.898264516416725
# Difference between R2 score and cross validation score is : 194.44238389994524

# %%
#Model initiation for RandomForestRegressor
name1= RandomForestRegressor()
name1.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
r2_score(name1,x_train,x_test,y_train,y_test,train=True)
r2_score(name1,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data 86.03164951601576
# r2_score: -0.7126789216196527
# Mean absolute error:- 15.764444444444443
# mean squared error:- 406.2643555555556
# Root mean squared error:- 20.156000485105064

# %% [markdown]
# r2 score using RandomForestRegressor is -71.26%

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score1=cross_val_score(name1,x1,y)
print(score1)
print(score1.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score1.mean())*100)
# Out:
# [-1.85157364 -0.17300786 -2.30184467 -0.52030553 -0.19276084]
# -1.0078985082957241
# Difference between R2 score and cross validation score is : 5.40578308784514

# %%
#Model initiation for KNN
name2=KNN()
name2.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
r2_score(name2,x_train,x_test,y_train,y_test,train=True)
r2_score(name2,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data -8.7506183394912
# r2_score: -0.5044904756948063
# Mean absolute error:- 16.26666666666667
# mean squared error:- 356.88000000000005
# Root mean squared error:- 18.89126782405035

# %% [markdown]
# r2 score using KNN is -50.44%

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score2=cross_val_score(name2,x1,y)
print(score2)
print(score2.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score2.mean())*100)
# Out:
# [-3.39937984 -0.00527851 -2.18746324 -0.78332596 -0.30053438]
# -1.3351963879221813
# Difference between R2 score and cross validation score is : 38.13557105049086

# %%
#Model initiation for GradientBoostingRegressor
name3=GradientBoostingRegressor()
name3.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
r2_score(name3,x_train,x_test,y_train,y_test,train=True)
r2_score(name3,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data 99.99996474182211
# r2_score: -1.165575240258808
# Mean absolute error:- 17.87434592780223
# mean squared error:- 513.6958353868239
# Root mean squared error:- 22.664859041847667

# %% [markdown]
# r2 score using GradientBoostingRegressor is -11.65%

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score3=cross_val_score(name3,x1,y)
print(score3)
print(score3.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score3.mean())*100)
# Out:
# [-1.16523333 -0.39770483 -2.90586338 -0.87938337 -0.31680447]
# -1.1329978751150218
# Difference between R2 score and cross validation score is : 17.915719769774906

# %%
#Model initiation for lasso
name4=Lasso()
name4.fit(x_train,y_train)
# Out:
# Lasso()

# %%
r2_score(name4,x_train,x_test,y_train,y_test,train=True)
r2_score(name4,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data 32.24077825098879
# r2_score: -0.8481796637172236
# Mean absolute error:- 15.692855554261541
# mean squared error:- 438.4064698600337
# Root mean squared error:- 20.93815822511698

# %% [markdown]
# r2 score using lasso is -84.81%

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score4=cross_val_score(name4,x1,y)
print(score4)
print(score4.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score4.mean())*100)
# Out:
# [-3.79384007 -0.11425609 -2.88566486 -0.12846842 -0.31913887]
# -1.4482736633267268
# Difference between R2 score and cross validation score is : 49.4432985909454

# %%
#Model initiation for Ridge
name5=Ridge()
name5.fit(x_train,y_train)
# Out:
# Ridge()

# %%
r2_score(name5,x_train,x_test,y_train,y_test,train=True)
r2_score(name5,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data 63.56137268827364
# r2_score: -0.7578939350062868
# Mean absolute error:- 16.581119742581944
# mean squared error:- 416.98980329889866
# Root mean squared error:- 20.420328187835246

# %% [markdown]
# r2 score using ridge is -75.78%

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score5=cross_val_score(name5,x1,y)
print(score5)
print(score5.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score5.mean())*100)
# Out:
# [-4.10289463 -0.52746153 -2.93115138 -0.81437028 -0.22813136]
# -1.7208018351979057
# Difference between R2 score and cross validation score is : 76.6961157780633

# %%
#Model initiation for DecisionTreeRegressor
name6=DecisionTreeRegressor()
name6.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
r2_score(name6,x_train,x_test,y_train,y_test,train=True)
r2_score(name6,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data 100.0
# r2_score: -1.1134589361923601
# Mean absolute error:- 18.0
# mean squared error:- 501.3333333333333
# Root mean squared error:- 22.390474164995553

# %% [markdown]
# r2 score using DecisionTree Regressor is -11.13%

# %%
y_pred=name6.predict(x_train)
y_test_p=name6.predict(x_train)

# %%
y_pred
# Out:
# array([ 86.,  95.,  88.,  90.,  93.,  88.,  92., 119., 101., 117.,  75.,
#         90., 116.,  95.,  94.,  79.,  85.,  77.,  88.,  77.,  86.])

# %%
y_test_p
# Out:
# array([ 86.,  95.,  88.,  90.,  93.,  88.,  92., 119., 101., 117.,  75.,
#         90., 116.,  95.,  94.,  79.,  85.,  77.,  88.,  77.,  86.])

# %%
print("r2_score on training data",metrics.r2_score(y_train,y_pred)*100)
print("r2_score:",metrics.r2_score(y_train,y_test_p))
print("Mean absolute error:-",mean_absolute_error(y_train,y_test_p))
print("mean squared error:-",mean_squared_error(y_train,y_test_p))
print("Root mean squared error:-",np.sqrt(mean_squared_error(y_train,y_test_p)))
# Out:
# r2_score on training data 100.0
# r2_score: 1.0
# Mean absolute error:- 0.0
# mean squared error:- 0.0
# Root mean squared error:- 0.0

# %% [markdown]
# If we done testing also on training data only then r2 score is 100%

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score6=cross_val_score(name6,x1,y)
print(score6)
print(score6.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score6.mean())*100)
# Out:
# [-0.01550388 -0.07128647 -2.45955882 -4.9360547  -0.43845817]
# -1.5841724072155277
# Difference between R2 score and cross validation score is : 63.033172979825494

# %%
from sklearn.ensemble import ExtraTreesRegressor
#Model initiation for ExtraTreesRegressor
name7=ExtraTreesRegressor()
name7.fit(x_train,y_train)
# Out:
# ExtraTreesRegressor()

# %%
r2_score(name7,x_train,x_test,y_train,y_test,train=True)
r2_score(name7,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data 100.0
# r2_score: -0.8194311283439164
# Mean absolute error:- 16.33
# mean squared error:- 431.5870333333334
# Root mean squared error:- 20.774672881500045

# %% [markdown]
# r2 score using ExtraTreesRegressor is -81.94%

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score7=cross_val_score(name7,x1,y)
print(score7)
print(score7.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score7.mean())*100)
# Out:
# [-0.96486124 -0.29463299 -2.55210616 -0.86338874 -0.05452633]
# -0.9459030906634156
# Difference between R2 score and cross validation score is : -0.793758675385714

# %%
from sklearn.svm import SVR
#Model initiation for SVR
name8=SVR()
name8.fit(x_train,y_train)
# Out:
# SVR()

# %%
r2_score(name8,x_train,x_test,y_train,y_test,train=True)
r2_score(name8,x_train,x_test,y_train,y_test,train=False)
# Out:
# r2_score on training data 9.128846908025212
# r2_score: -0.5055150512920856
# Mean absolute error:- 13.88038591195655
# mean squared error:- 357.12303945093987
# Root mean squared error:- 18.897699316343772

# %% [markdown]
# r2 score using SVR is -50.55%

# %%
#finding cv score
from sklearn.model_selection import cross_val_score
score8=cross_val_score(name8,x1,y)
print(score8)
print(score8.mean())
print("Difference between R2 score and cross validation score is :",(metrics.r2_score(y_test,y_test_pred)-score8.mean())*100)
# Out:
# [-0.75817614 -0.17756215 -1.94203151  0.00715273 -0.00345478]
# -0.5748143701193926
# Difference between R2 score and cross validation score is : -37.902630729788015

# %% [markdown]
# from the difference of both r2_score and cross validation score computed on r2 score we can conclude that ExtraTreesRegressor as our best fitting model.

# %% [markdown]
# Hyper Parameter Tuning:

# %%
from sklearn.model_selection import GridSearchCV

# %%
param={'criterion':["squared_error", "absolute_error", "friedman_mse", "poisson"],
      'random_state':[10,50,100],
       'max_depth':[10,20],
       'n_jobs':[-2,-1,1],
      'n_estimators':[50,100,200]}

# %%
GSV=GridSearchCV(ExtraTreesRegressor(),param,cv=5)

# %%
GSV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesRegressor(),
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_depth': [10, 20], 'n_estimators': [50, 100, 200],
#                          'n_jobs': [-2, -1, 1], 'random_state': [10, 50, 100]})

# %%
GSV.best_params_
# Out:
# {'criterion': 'poisson',
#  'max_depth': 10,
#  'n_estimators': 50,
#  'n_jobs': -2,
#  'random_state': 100}

# %%
Model=ExtraTreesRegressor(criterion='poisson',max_depth=10,n_estimators=50,n_jobs=-2,random_state=100)

# %%
Model.fit(x_train,y_train)
pred=Model.predict(x_test)

# %%
print("r2_score on training data",metrics.r2_score(y_train[0:9],pred)*100)
# Out:
# r2_score on training data -79.4188940427627

# %%
print("R2_score:",metrics.r2_score(y_test,pred))
print("Mean Absolute error:",mean_absolute_error(y_test,pred))
print("mean squared error:",mean_squared_error(y_test,pred))
print("Root mean squared error:",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score: -0.15576106308713933
# Mean Absolute error: 12.660629629629629
# mean squared error: 204.95496185411938
# Root mean squared error: 14.31624817660407

# %%
#to save the model
import pickle
file_name="Base_ball_project.pkl"
pickle.dump(Model,open(file_name,'wb'))

# %%
import pickle
loaded_model=pickle.load(open('Base_ball_project.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# -15.576106308713932

# %%
PR_OR_df=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=["predicted","original"])
PR_OR_df
# Out:
#                0       1          2       3       4       5          6  \
# predicted   99.5  104.02  87.439381  101.78  105.82   99.93  92.834333
# original   117.0   95.00  79.000000   77.00   88.00  116.00  94.000000
#
#                 7          8
# predicted  101.94  82.789381
# original    90.00  90.000000
